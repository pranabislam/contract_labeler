# %%
import json
import pandas as pd
import ast
import math

# %%
all_nodes_path = "/Users/rohith/Downloads/all_contract_text.json"
highlighted_nodes_path = "/Users/rohith/Downloads/contract_saved.json"
with open(all_nodes_path, encoding='UTF-8') as f:
    all_nodes_data = json.load(f)
with open(highlighted_nodes_path, encoding='UTF-8') as f:
    highlighted_data = json.load(f)

# %%
all_nodes_xpaths = ast.literal_eval(all_nodes_data['xpaths'])
all_nodes_segmented_text = ast.literal_eval(all_nodes_data['segmentedTexts'])
df = pd.DataFrame()
df['xpaths'] = all_nodes_xpaths
df['text'] = all_nodes_segmented_text
df['all_nodes_ordering'] = df.index.copy()

# %%
highlighted_data['c']
# Out:
# '[["2832px","598.539px","242.922px","15px"],["3331.5px","685.602px","68.7969px","15px"],["3362.5px","675.922px","88.1562px","15px"],["3393.5px","104px","67.6484px","15px"],["3393.5px","199.648px","63.3203px","15px"],["3672.5px","716.664px","6.67188px","15px"],["4094.5px","716.664px","6.67188px","15px"],["4532px","716.664px","6.67188px","15px"],["4876.5px","716.664px","6.67188px","15px"],["5236.5px","716.664px","6.67188px","15px"],["5689.5px","716.664px","6.67188px","15px"],["6158px","716.664px","6.67188px","15px"],["6704px","716.664px","6.67188px","15px"],["7157px","713.328px","13.3359px","15px"],["7594.5px","713.578px","12.8359px","15px"],["7954.5px","713.328px","13.3359px","15px"],["8283.5px","713.328px","13.3359px","15px"],["8705.5px","713.328px","13.3359px","15px"],["9143px","713.328px","13.3359px","15px"],["9580.5px","713.328px","13.3359px","15px"],["10080px","713.328px","13.3359px","15px"],["10841px","713.328px","13.3359px","15px"],["11619.5px","713.328px","13.3359px","15px"],"DELETED",["12212px","104px","66.6484px","15px"],["12212px","199.648px","258.766px","15px"],["12289.5px","713.328px","13.3359px","15px"],["12572px","683.008px","73.9844px","15px"],["12603px","639.758px","160.484px","15px"],["12634px","104px","66.6484px","15px"],["12634px","197.648px","46.8203px","15px"],["12680.5px","713.328px","13.3359px","15px"],["12792.5px","104px","66.6484px","15px"],["12792.5px","199.648px","71.5703px","15px"],["13087px","713.328px","13.3359px","15px"],["13137px","104px","66.6484px","15px"],["13137px","199.648px","314.07px","15px"],["13462.5px","104px","66.6484px","15px"],"DELETED",["13462.5px","199.648px","235.586px","15px"],["13509px","713.328px","13.3359px","15px"],["13621px","104px","66.6484px","15px"],["13621px","199.648px","128.461px","15px"],["13869px","713.328px","13.3359px","15px"],["14244.5px","713.328px","13.3359px","15px"],["14589px","713.328px","13.3359px","15px"],"DELETED",["14639px","104px","66.6484px","15px"],["14639px","199.648px","99.2344px","15px"],["14825px","104px","66.6484px","15px"],["14825px","199.648px","136.891px","15px"],"DELETED",["14949px","713.328px","13.3359px","15px"],["15340px","713.328px","13.3359px","15px"],["15638px","104px","66.6484px","15px"],["15638px","199.648px","70.7344px","15px"],["15715.5px","713.328px","13.3359px","15px"],["15765.5px","104px","66.6484px","15px"],["15765.5px","199.648px","91.8359px","15px"],["15827.5px","104px","66.6484px","15px"],["15827.5px","199.648px","108.336px","15px"],["15889.5px","104px","66.1562px","15px"],["15889.5px","199.156px","91.8047px","15px"],["15967px","104px","68.6484px","15px"],["15967px","199.648px","105.883px","15px"]]'

# %%
highlight_xpaths = ast.literal_eval(highlighted_data['xpaths'])
highlight_segmented_text = ast.literal_eval(highlighted_data['segmentedTexts'])
highlight_text = ast.literal_eval(highlighted_data['texts'])
highlight_labels = ast.literal_eval(highlighted_data['labels'])
highlight_coordinates = ast.literal_eval(highlighted_data['c'])
highlighted_df = pd.DataFrame()
highlighted_df['highlighted_xpaths'] = highlight_xpaths
highlighted_df['highlighted_segmented_text'] = highlight_segmented_text
highlighted_df['highlighted_labels'] = highlight_labels
highlighted_df['highlighted_coordinates'] = highlight_coordinates
highlighted_df['segment_number_from_idx'] = highlighted_df.index.copy()
highlighted_df['num_entries_1'] = highlighted_df['highlighted_xpaths'].apply(len)
highlighted_df['num_entries_2'] = highlighted_df['highlighted_segmented_text'].apply(len)

# %%
assert highlighted_df['num_entries_1'].equals(highlighted_df['num_entries_2']), 'Mismatch in segmentation and groupings'
print("There is no mismatch in segmentations and groupings, we can proceed")
# Out:
# There is no mismatch in segmentations and groupings, we can proceed

# %%
exploded_highlight_df = highlighted_df[
    ['highlighted_xpaths','highlighted_segmented_text','highlighted_labels',
     'segment_number_from_idx','highlighted_coordinates','num_entries_1']
    ].explode(column=['highlighted_xpaths','highlighted_segmented_text']).reset_index(drop=True)

exploded_highlight_df['exploded_highlight_node_order'] = exploded_highlight_df.index.copy()

# %%
exploded_highlight_df = exploded_highlight_df[exploded_highlight_df['highlighted_xpaths'] != 'DELETED'].dropna()

# %%
exploded_highlight_df['top'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[0][:-2]))
exploded_highlight_df['left'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[1][:-2]))
exploded_highlight_df['width'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[2][:-2]))
exploded_highlight_df['height'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[3][:-2]))

# %%
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# ..                                                ...
# 74  /html/body/document/type/sequence/filename/des...
# 75  /html/body/document/type/sequence/filename/des...
# 76  /html/body/document/type/sequence/filename/des...
# 77  /html/body/document/type/sequence/filename/des...
# 78  /html/body/document/type/sequence/filename/des...
#
#       highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 0   AGREEMENT AND PLAN OF MERGER                  t                        0
# 1                      ARTICLE I                 sn                        1
# 2                    DEFINITIONS                 st                        2
# 3                   Section 1.01                ssn                        3
# 4                    Definitions                sst                        4
# ..                           ...                ...                      ...
# 74             Lost Certificates                sst                       62
# 75                             .                sst                       62
# 76                  Section 2.12                ssn                       63
# 77            Further Assurances                sst                       64
# 78                             .                sst                       64
#
#                     highlighted_coordinates  num_entries_1  \
# 0      [2832px, 598.539px, 242.922px, 15px]              1
# 1    [3331.5px, 685.602px, 68.7969px, 15px]              1
# 2    [3362.5px, 675.922px, 88.1562px, 15px]              1
# 3        [3393.5px, 104px, 67.6484px, 15px]              1
# 4    [3393.5px, 199.648px, 63.3203px, 15px]              2
# ..                                      ...            ...
# 74  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 75  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 76        [15967px, 104px, 68.6484px, 15px]              1
# 77    [15967px, 199.648px, 105.883px, 15px]              2
# 78    [15967px, 199.648px, 105.883px, 15px]              2
#
#     exploded_highlight_node_order      top     left     width  height
# 0                               0   2832.0  598.539  242.9220    15.0
# 1                               1   3331.5  685.602   68.7969    15.0
# 2                               2   3362.5  675.922   88.1562    15.0
# 3                               3   3393.5  104.000   67.6484    15.0
# 4                               4   3393.5  199.648   63.3203    15.0
# ..                            ...      ...      ...       ...     ...
# 74                             74  15889.5  199.156   91.8047    15.0
# 75                             75  15889.5  199.156   91.8047    15.0
# 76                             76  15967.0  104.000   68.6484    15.0
# 77                             77  15967.0  199.648  105.8830    15.0
# 78                             78  15967.0  199.648  105.8830    15.0
#
# [75 rows x 11 columns]

# %% [markdown]
# Okay so far looks like we can do logic:
# 1. Sort by top and then if theres a tiebreaker, sort by left, and then sort by order in the highlight list (in the case of multiple nodes being highlighted in same row with 1 highlight box)
# 2. If it starts to show that top coordinates are not exact and are approximaate, we are going to need to start doing approximate sorting or some IOU related logic to post process this to infer if something is the same line (which seems extremely likely to work)

# %%
def sort_exploded_highlight_box_by_coordinates(exploded_highlight_df):
    '''
    If logic ever has to deal with approximations and some line inference (with IOU math),
    then this function will become more complicated but for now it seems okay
    '''
    return exploded_highlight_df.sort_values(by=['top','left','exploded_highlight_node_order']).reset_index(drop=True)

# %%
exploded_highlight_df = sort_exploded_highlight_box_by_coordinates(exploded_highlight_df)
exploded_highlight_df['exploded_highlight_node_order'] = exploded_highlight_df.index.copy()
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# ..                                                ...
# 70  /html/body/document/type/sequence/filename/des...
# 71  /html/body/document/type/sequence/filename/des...
# 72  /html/body/document/type/sequence/filename/des...
# 73  /html/body/document/type/sequence/filename/des...
# 74  /html/body/document/type/sequence/filename/des...
#
#       highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 0   AGREEMENT AND PLAN OF MERGER                  t                        0
# 1                      ARTICLE I                 sn                        1
# 2                    DEFINITIONS                 st                        2
# 3                   Section 1.01                ssn                        3
# 4                    Definitions                sst                        4
# ..                           ...                ...                      ...
# 70             Lost Certificates                sst                       62
# 71                             .                sst                       62
# 72                  Section 2.12                ssn                       63
# 73            Further Assurances                sst                       64
# 74                             .                sst                       64
#
#                     highlighted_coordinates  num_entries_1  \
# 0      [2832px, 598.539px, 242.922px, 15px]              1
# 1    [3331.5px, 685.602px, 68.7969px, 15px]              1
# 2    [3362.5px, 675.922px, 88.1562px, 15px]              1
# 3        [3393.5px, 104px, 67.6484px, 15px]              1
# 4    [3393.5px, 199.648px, 63.3203px, 15px]              2
# ..                                      ...            ...
# 70  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 71  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 72        [15967px, 104px, 68.6484px, 15px]              1
# 73    [15967px, 199.648px, 105.883px, 15px]              2
# 74    [15967px, 199.648px, 105.883px, 15px]              2
#
#     exploded_highlight_node_order      top     left     width  height
# 0                               0   2832.0  598.539  242.9220    15.0
# 1                               1   3331.5  685.602   68.7969    15.0
# 2                               2   3362.5  675.922   88.1562    15.0
# 3                               3   3393.5  104.000   67.6484    15.0
# 4                               4   3393.5  199.648   63.3203    15.0
# ..                            ...      ...      ...       ...     ...
# 70                             70  15889.5  199.156   91.8047    15.0
# 71                             71  15889.5  199.156   91.8047    15.0
# 72                             72  15967.0  104.000   68.6484    15.0
# 73                             73  15967.0  199.648  105.8830    15.0
# 74                             74  15967.0  199.648  105.8830    15.0
#
# [75 rows x 11 columns]

# %%
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# ..                                                ...
# 70  /html/body/document/type/sequence/filename/des...
# 71  /html/body/document/type/sequence/filename/des...
# 72  /html/body/document/type/sequence/filename/des...
# 73  /html/body/document/type/sequence/filename/des...
# 74  /html/body/document/type/sequence/filename/des...
#
#       highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 0   AGREEMENT AND PLAN OF MERGER                  t                        0
# 1                      ARTICLE I                 sn                        1
# 2                    DEFINITIONS                 st                        2
# 3                   Section 1.01                ssn                        3
# 4                    Definitions                sst                        4
# ..                           ...                ...                      ...
# 70             Lost Certificates                sst                       62
# 71                             .                sst                       62
# 72                  Section 2.12                ssn                       63
# 73            Further Assurances                sst                       64
# 74                             .                sst                       64
#
#                     highlighted_coordinates  num_entries_1  \
# 0      [2832px, 598.539px, 242.922px, 15px]              1
# 1    [3331.5px, 685.602px, 68.7969px, 15px]              1
# 2    [3362.5px, 675.922px, 88.1562px, 15px]              1
# 3        [3393.5px, 104px, 67.6484px, 15px]              1
# 4    [3393.5px, 199.648px, 63.3203px, 15px]              2
# ..                                      ...            ...
# 70  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 71  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 72        [15967px, 104px, 68.6484px, 15px]              1
# 73    [15967px, 199.648px, 105.883px, 15px]              2
# 74    [15967px, 199.648px, 105.883px, 15px]              2
#
#     exploded_highlight_node_order      top     left     width  height
# 0                               0   2832.0  598.539  242.9220    15.0
# 1                               1   3331.5  685.602   68.7969    15.0
# 2                               2   3362.5  675.922   88.1562    15.0
# 3                               3   3393.5  104.000   67.6484    15.0
# 4                               4   3393.5  199.648   63.3203    15.0
# ..                            ...      ...      ...       ...     ...
# 70                             70  15889.5  199.156   91.8047    15.0
# 71                             71  15889.5  199.156   91.8047    15.0
# 72                             72  15967.0  104.000   68.6484    15.0
# 73                             73  15967.0  199.648  105.8830    15.0
# 74                             74  15967.0  199.648  105.8830    15.0
#
# [75 rows x 11 columns]

# %%
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# ..                                                ...
# 70  /html/body/document/type/sequence/filename/des...
# 71  /html/body/document/type/sequence/filename/des...
# 72  /html/body/document/type/sequence/filename/des...
# 73  /html/body/document/type/sequence/filename/des...
# 74  /html/body/document/type/sequence/filename/des...
#
#       highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 0   AGREEMENT AND PLAN OF MERGER                  t                        0
# 1                      ARTICLE I                 sn                        1
# 2                    DEFINITIONS                 st                        2
# 3                   Section 1.01                ssn                        3
# 4                    Definitions                sst                        4
# ..                           ...                ...                      ...
# 70             Lost Certificates                sst                       62
# 71                             .                sst                       62
# 72                  Section 2.12                ssn                       63
# 73            Further Assurances                sst                       64
# 74                             .                sst                       64
#
#                     highlighted_coordinates  num_entries_1  \
# 0      [2832px, 598.539px, 242.922px, 15px]              1
# 1    [3331.5px, 685.602px, 68.7969px, 15px]              1
# 2    [3362.5px, 675.922px, 88.1562px, 15px]              1
# 3        [3393.5px, 104px, 67.6484px, 15px]              1
# 4    [3393.5px, 199.648px, 63.3203px, 15px]              2
# ..                                      ...            ...
# 70  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 71  [15889.5px, 199.156px, 91.8047px, 15px]              2
# 72        [15967px, 104px, 68.6484px, 15px]              1
# 73    [15967px, 199.648px, 105.883px, 15px]              2
# 74    [15967px, 199.648px, 105.883px, 15px]              2
#
#     exploded_highlight_node_order      top     left     width  height
# 0                               0   2832.0  598.539  242.9220    15.0
# 1                               1   3331.5  685.602   68.7969    15.0
# 2                               2   3362.5  675.922   88.1562    15.0
# 3                               3   3393.5  104.000   67.6484    15.0
# 4                               4   3393.5  199.648   63.3203    15.0
# ..                            ...      ...      ...       ...     ...
# 70                             70  15889.5  199.156   91.8047    15.0
# 71                             71  15889.5  199.156   91.8047    15.0
# 72                             72  15967.0  104.000   68.6484    15.0
# 73                             73  15967.0  199.648  105.8830    15.0
# 74                             74  15967.0  199.648  105.8830    15.0
#
# [75 rows x 11 columns]

# %%
def monotonic_left_merge(full, highlighted):
    found_xpaths = []
    merged_df = []
    for row in full.iterrows():
        full_xpaths = row[1]['xpaths']
        full_texts = row[1]['text']
        matched_hrow = pd.Series([])
        # print(full_texts, full_xpaths)
        for h_row in highlighted.iterrows():
            h_xpaths = h_row[1]['highlighted_xpaths']
            h_texts = h_row[1]['highlighted_segmented_text']

            if h_xpaths == full_xpaths and h_texts == full_texts:
                if h_xpaths in found_xpaths:
                    # print('CURRENT h_xpath ALREADY FOUND BEFORE')
                    # print(h_xpaths)
                    _
                    
                found_xpaths.append(h_xpaths)
                # Instead of below, save the specific 
                # h_row and as you build the merged_df 
                # in the outer loop of all nodes, for 
                # the highlight matched rows, append 
                # the h_row as well.
                
                # merged_df.append((row, h_row))
                matched_hrow = h_row
                break
        if len(matched_hrow) == 0:
            # print('No matched highlighted xpaths', full_xpaths)
            merged_df.append(row)
        else:
            print(row[1], matched_hrow[1])
            print(pd.concat([row[1], matched_hrow[1]], axis=1))
            merged_df.append(pd.concat([row[1], matched_hrow[1]], axis=1))
        
    return merged_df

# %%
merged_df = monotonic_left_merge(df, exploded_highlight_df)
# Out:
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                       AGREEMENT AND PLAN OF MERGER
# all_nodes_ordering                                                  380
# Name: 380, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                            AGREEMENT AND PLAN OF MERGER
# highlighted_labels                                                               t
# segment_number_from_idx                                                          0
# highlighted_coordinates                       [2832px, 598.539px, 242.922px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    0
# top                                                                         2832.0
# left                                                                       598.539
# width                                                                      242.922
# height                                                                        15.0
# Name: 0, dtype: object
#                                                                              380  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                AGREEMENT AND PLAN OF MERGER
# all_nodes_ordering                                                           380
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              0
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                          AGREEMENT AND PLAN OF MERGER
# highlighted_labels                                                             t
# segment_number_from_idx                                                        0
# highlighted_coordinates                     [2832px, 598.539px, 242.922px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  0
# top                                                                       2832.0
# left                                                                     598.539
# width                                                                    242.922
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                          ARTICLE I
# all_nodes_ordering                                                  405
# Name: 405, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                               ARTICLE I
# highlighted_labels                                                              sn
# segment_number_from_idx                                                          1
# highlighted_coordinates                     [3331.5px, 685.602px, 68.7969px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    1
# top                                                                         3331.5
# left                                                                       685.602
# width                                                                      68.7969
# height                                                                        15.0
# Name: 1, dtype: object
#                                                                              405  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                   ARTICLE I
# all_nodes_ordering                                                           405
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              1
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                             ARTICLE I
# highlighted_labels                                                            sn
# segment_number_from_idx                                                        1
# highlighted_coordinates                   [3331.5px, 685.602px, 68.7969px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  1
# top                                                                       3331.5
# left                                                                     685.602
# width                                                                    68.7969
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                        DEFINITIONS
# all_nodes_ordering                                                  406
# Name: 406, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                             DEFINITIONS
# highlighted_labels                                                              st
# segment_number_from_idx                                                          2
# highlighted_coordinates                     [3362.5px, 675.922px, 88.1562px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    2
# top                                                                         3362.5
# left                                                                       675.922
# width                                                                      88.1562
# height                                                                        15.0
# Name: 2, dtype: object
#                                                                              406  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                 DEFINITIONS
# all_nodes_ordering                                                           406
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              2
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                           DEFINITIONS
# highlighted_labels                                                            st
# segment_number_from_idx                                                        2
# highlighted_coordinates                   [3362.5px, 675.922px, 88.1562px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  2
# top                                                                       3362.5
# left                                                                     675.922
# width                                                                    88.1562
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                       Section 1.01
# all_nodes_ordering                                                  407
# Name: 407, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                            Section 1.01
# highlighted_labels                                                             ssn
# segment_number_from_idx                                                          3
# highlighted_coordinates                         [3393.5px, 104px, 67.6484px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    3
# top                                                                         3393.5
# left                                                                         104.0
# width                                                                      67.6484
# height                                                                        15.0
# Name: 3, dtype: object
#                                                                              407  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                Section 1.01
# all_nodes_ordering                                                           407
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              3
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                          Section 1.01
# highlighted_labels                                                           ssn
# segment_number_from_idx                                                        3
# highlighted_coordinates                       [3393.5px, 104px, 67.6484px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  3
# top                                                                       3393.5
# left                                                                       104.0
# width                                                                    67.6484
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                        Definitions
# all_nodes_ordering                                                  408
# Name: 408, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                             Definitions
# highlighted_labels                                                             sst
# segment_number_from_idx                                                          4
# highlighted_coordinates                     [3393.5px, 199.648px, 63.3203px, 15px]
# num_entries_1                                                                    2
# exploded_highlight_node_order                                                    4
# top                                                                         3393.5
# left                                                                       199.648
# width                                                                      63.3203
# height                                                                        15.0
# Name: 4, dtype: object
#                                                                              408  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                 Definitions
# all_nodes_ordering                                                           408
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              4
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                           Definitions
# highlighted_labels                                                           sst
# segment_number_from_idx                                                        4
# highlighted_coordinates                   [3393.5px, 199.648px, 63.3203px, 15px]
# num_entries_1                                                                  2
# exploded_highlight_node_order                                                  4
# top                                                                       3393.5
# left                                                                     199.648
# width                                                                    63.3203
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  .
# all_nodes_ordering                                                  409
# Name: 409, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       .
# highlighted_labels                                                             sst
# segment_number_from_idx                                                          4
# highlighted_coordinates                     [3393.5px, 199.648px, 63.3203px, 15px]
# num_entries_1                                                                    2
# exploded_highlight_node_order                                                    5
# top                                                                         3393.5
# left                                                                       199.648
# width                                                                      63.3203
# height                                                                        15.0
# Name: 5, dtype: object
#                                                                              409  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           .
# all_nodes_ordering                                                           409
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              5
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     .
# highlighted_labels                                                           sst
# segment_number_from_idx                                                        4
# highlighted_coordinates                   [3393.5px, 199.648px, 63.3203px, 15px]
# num_entries_1                                                                  2
# exploded_highlight_node_order                                                  5
# top                                                                       3393.5
# left                                                                     199.648
# width                                                                    63.3203
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  2
# all_nodes_ordering                                                  428
# Name: 428, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       2
# highlighted_labels                                                               n
# segment_number_from_idx                                                          5
# highlighted_coordinates                     [3672.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    6
# top                                                                         3672.5
# left                                                                       716.664
# width                                                                      6.67188
# height                                                                        15.0
# Name: 6, dtype: object
#                                                                              428  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           2
# all_nodes_ordering                                                           428
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              6
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     2
# highlighted_labels                                                             n
# segment_number_from_idx                                                        5
# highlighted_coordinates                   [3672.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  6
# top                                                                       3672.5
# left                                                                     716.664
# width                                                                    6.67188
# height                                                                      15.0
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  3
# all_nodes_ordering                                                  451
# Name: 451, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       3
# highlighted_labels                                                               n
# segment_number_from_idx                                                          6
# highlighted_coordinates                     [4094.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    7
# top                                                                         4094.5
# left                                                                       716.664
# width                                                                      6.67188
# height                                                                        15.0
# Name: 7, dtype: object
#                                                                              451  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           3
# all_nodes_ordering                                                           451
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              7
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     3
# highlighted_labels                                                             n
# segment_number_from_idx                                                        6
# highlighted_coordinates                   [4094.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  7
# top                                                                       4094.5
# left                                                                     716.664
# width                                                                    6.67188
# height                                                                      15.0
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  4
# all_nodes_ordering                                                  479
# Name: 479, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       4
# highlighted_labels                                                               n
# segment_number_from_idx                                                          7
# highlighted_coordinates                       [4532px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    8
# top                                                                         4532.0
# left                                                                       716.664
# width                                                                      6.67188
# height                                                                        15.0
# Name: 8, dtype: object
#                                                                              479  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           4
# all_nodes_ordering                                                           479
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              8
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     4
# highlighted_labels                                                             n
# segment_number_from_idx                                                        7
# highlighted_coordinates                     [4532px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  8
# top                                                                       4532.0
# left                                                                     716.664
# width                                                                    6.67188
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  5
# all_nodes_ordering                                                  503
# Name: 503, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       5
# highlighted_labels                                                               n
# segment_number_from_idx                                                          8
# highlighted_coordinates                     [4876.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                    9
# top                                                                         4876.5
# left                                                                       716.664
# width                                                                      6.67188
# height                                                                        15.0
# Name: 9, dtype: object
#                                                                              503  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           5
# all_nodes_ordering                                                           503
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              9
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     5
# highlighted_labels                                                             n
# segment_number_from_idx                                                        8
# highlighted_coordinates                   [4876.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                  9
# top                                                                       4876.5
# left                                                                     716.664
# width                                                                    6.67188
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  6
# all_nodes_ordering                                                  512
# Name: 512, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       6
# highlighted_labels                                                               n
# segment_number_from_idx                                                          9
# highlighted_coordinates                     [5236.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                   10
# top                                                                         5236.5
# left                                                                       716.664
# width                                                                      6.67188
# height                                                                        15.0
# Name: 10, dtype: object
#                                                                              512  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           6
# all_nodes_ordering                                                           512
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              10
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     6
# highlighted_labels                                                             n
# segment_number_from_idx                                                        9
# highlighted_coordinates                   [5236.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                 10
# top                                                                       5236.5
# left                                                                     716.664
# width                                                                    6.67188
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  7
# all_nodes_ordering                                                  543
# Name: 543, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       7
# highlighted_labels                                                               n
# segment_number_from_idx                                                         10
# highlighted_coordinates                     [5689.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                   11
# top                                                                         5689.5
# left                                                                       716.664
# width                                                                      6.67188
# height                                                                        15.0
# Name: 11, dtype: object
#                                                                              543  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                           7
# all_nodes_ordering                                                           543
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                              11
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                     7
# highlighted_labels                                                             n
# segment_number_from_idx                                                       10
# highlighted_coordinates                   [5689.5px, 716.664px, 6.67188px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                 11
# top                                                                       5689.5
# left                                                                     716.664
# width                                                                    6.67188
# height                                                                      15.0
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# <ipython-input-482-4e82d15bb48d>:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   matched_hrow = pd.Series([])
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                                  8
# all_nodes_ordering                                                  579
# Name: 579, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                                       8
# highlighted_labels                                                               n
# segment_number_from_idx                                                         11
# ...
#
#                                                                             67
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                    Withholding Rights
# highlighted_labels                                                           sst
# segment_number_from_idx                                                       60
# highlighted_coordinates                  [15827.5px, 199.648px, 108.336px, 15px]
# num_entries_1                                                                  2
# exploded_highlight_node_order                                                 67
# top                                                                      15827.5
# left                                                                     199.648
# width                                                                    108.336
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                       Section 2.11
# all_nodes_ordering                                                 1365
# Name: 1365, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                            Section 2.11
# highlighted_labels                                                             ssn
# segment_number_from_idx                                                         61
# highlighted_coordinates                        [15889.5px, 104px, 66.1562px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                   69
# top                                                                        15889.5
# left                                                                         104.0
# width                                                                      66.1562
# height                                                                        15.0
# Name: 69, dtype: object
#                                                                             1365  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                Section 2.11
# all_nodes_ordering                                                          1365
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                             69
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                          Section 2.11
# highlighted_labels                                                           ssn
# segment_number_from_idx                                                       61
# highlighted_coordinates                      [15889.5px, 104px, 66.1562px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                 69
# top                                                                      15889.5
# left                                                                       104.0
# width                                                                    66.1562
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                  Lost Certificates
# all_nodes_ordering                                                 1366
# Name: 1366, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                       Lost Certificates
# highlighted_labels                                                             sst
# segment_number_from_idx                                                         62
# highlighted_coordinates                    [15889.5px, 199.156px, 91.8047px, 15px]
# num_entries_1                                                                    2
# exploded_highlight_node_order                                                   70
# top                                                                        15889.5
# left                                                                       199.156
# width                                                                      91.8047
# height                                                                        15.0
# Name: 70, dtype: object
#                                                                             1366  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                           Lost Certificates
# all_nodes_ordering                                                          1366
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                             70
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                     Lost Certificates
# highlighted_labels                                                           sst
# segment_number_from_idx                                                       62
# highlighted_coordinates                  [15889.5px, 199.156px, 91.8047px, 15px]
# num_entries_1                                                                  2
# exploded_highlight_node_order                                                 70
# top                                                                      15889.5
# left                                                                     199.156
# width                                                                    91.8047
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                       Section 2.12
# all_nodes_ordering                                                 1372
# Name: 1372, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                            Section 2.12
# highlighted_labels                                                             ssn
# segment_number_from_idx                                                         63
# highlighted_coordinates                          [15967px, 104px, 68.6484px, 15px]
# num_entries_1                                                                    1
# exploded_highlight_node_order                                                   72
# top                                                                        15967.0
# left                                                                         104.0
# width                                                                      68.6484
# height                                                                        15.0
# Name: 72, dtype: object
#                                                                             1372  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                                Section 2.12
# all_nodes_ordering                                                          1372
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                             72
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                          Section 2.12
# highlighted_labels                                                           ssn
# segment_number_from_idx                                                       63
# highlighted_coordinates                        [15967px, 104px, 68.6484px, 15px]
# num_entries_1                                                                  1
# exploded_highlight_node_order                                                 72
# top                                                                      15967.0
# left                                                                       104.0
# width                                                                    68.6484
# height                                                                      15.0
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                 Further Assurances
# all_nodes_ordering                                                 1373
# Name: 1373, dtype: object highlighted_xpaths               /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                      Further Assurances
# highlighted_labels                                                             sst
# segment_number_from_idx                                                         64
# highlighted_coordinates                      [15967px, 199.648px, 105.883px, 15px]
# num_entries_1                                                                    2
# exploded_highlight_node_order                                                   73
# top                                                                        15967.0
# left                                                                       199.648
# width                                                                      105.883
# height                                                                        15.0
# Name: 73, dtype: object
#                                                                             1373  \
# xpaths                         /html/body/document/type/sequence/filename/des...
# text                                                          Further Assurances
# all_nodes_ordering                                                          1373
# highlighted_xpaths                                                           NaN
# highlighted_segmented_text                                                   NaN
# highlighted_labels                                                           NaN
# segment_number_from_idx                                                      NaN
# highlighted_coordinates                                                      NaN
# num_entries_1                                                                NaN
# exploded_highlight_node_order                                                NaN
# top                                                                          NaN
# left                                                                         NaN
# width                                                                        NaN
# height                                                                       NaN
#
#                                                                             73
# xpaths                                                                       NaN
# text                                                                         NaN
# all_nodes_ordering                                                           NaN
# highlighted_xpaths             /html/body/document/type/sequence/filename/des...
# highlighted_segmented_text                                    Further Assurances
# highlighted_labels                                                           sst
# segment_number_from_idx                                                       64
# highlighted_coordinates                    [15967px, 199.648px, 105.883px, 15px]
# num_entries_1                                                                  2
# exploded_highlight_node_order                                                 73
# top                                                                      15967.0
# left                                                                     199.648
# width                                                                    105.883
# height                                                                      15.0

# %%
df.iloc[1087]
# Out:
# xpaths                /html/body/document/type/sequence/filename/des...
# text                                                CLOSING; THE MERGER
# all_nodes_ordering                                                 1087
# Name: 1087, dtype: object

# %%
pd.DataFrame(merged_df)[1]
# Out:
# xpaths                /html/body/document/type
# text                                    EX-4.7
# all_nodes_ordering                           0
# Name: 0, dtype: object

# %%
merged_df[1087]
# Out:
# ((1087,
#   xpaths                /html/body/document/type/sequence/filename/des...
#   text                                                CLOSING; THE MERGER
#   all_nodes_ordering                                                 1087
#   Name: 1087, dtype: object),
#  (29,
#   highlighted_xpaths               /html/body/document/type/sequence/filename/des...
#   highlighted_segmented_text                                     CLOSING; THE MERGER
#   highlighted_labels                                                              st
#   segment_number_from_idx                                                         28
#   highlighted_coordinates                      [12603px, 639.758px, 160.484px, 15px]
#   num_entries_1                                                                    1
#   exploded_highlight_node_order                                                   29
#   top                                                                        12603.0
#   left                                                                       639.758
#   width                                                                      160.484
#   height                                                                        15.0
#   Name: 29, dtype: object))

# %%
merged = pd.merge(df, exploded_highlight_df, left_on='xpaths', right_on='highlighted_xpaths', how='left', indicator=True)
merged.iloc[1087:1097]
# Out:
#                                                  xpaths  \
# 1087  /html/body/document/type/sequence/filename/des...
# 1088  /html/body/document/type/sequence/filename/des...
# 1089  /html/body/document/type/sequence/filename/des...
# 1090  /html/body/document/type/sequence/filename/des...
# 1091  /html/body/document/type/sequence/filename/des...
# 1092  /html/body/document/type/sequence/filename/des...
# 1093  /html/body/document/type/sequence/filename/des...
# 1094  /html/body/document/type/sequence/filename/des...
# 1095  /html/body/document/type/sequence/filename/des...
# 1096  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 1087                                CLOSING; THE MERGER                1087
# 1088                                       Section 2.01                1088
# 1089                                            Closing                1089
# 1090               .  The closing of the Mergers (the “                1090
# 1091                                            Closing                1091
# 1092  ”) shall take place in New York City at the of...                1092
# 1093                           Prospective Closing Date                1093
# 1094      ”) after the date the conditions set forth in                1094
# 1095                                         Article IX                1095
# 1096  (other than conditions that by their nature ar...                1096
#
#                                      highlighted_xpaths  \
# 1087  /html/body/document/type/sequence/filename/des...
# 1088  /html/body/document/type/sequence/filename/des...
# 1089  /html/body/document/type/sequence/filename/des...
# 1090  /html/body/document/type/sequence/filename/des...
# 1091                                                NaN
# 1092  /html/body/document/type/sequence/filename/des...
# 1093                                                NaN
# 1094  /html/body/document/type/sequence/filename/des...
# 1095                                                NaN
# 1096  /html/body/document/type/sequence/filename/des...
#
#      highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 1087        CLOSING; THE MERGER                 st                     28.0
# 1088               Section 2.01                ssn                     29.0
# 1089                    Closing                sst                     30.0
# 1090                          .                sst                     30.0
# 1091                        NaN                NaN                      NaN
# 1092                          .                sst                     30.0
# 1093                        NaN                NaN                      NaN
# 1094                          .                sst                     30.0
# 1095                        NaN                NaN                      NaN
# 1096                          .                sst                     30.0
#
#                     highlighted_coordinates  num_entries_1  \
# 1087  [12603px, 639.758px, 160.484px, 15px]            1.0
# 1088      [12634px, 104px, 66.6484px, 15px]            1.0
# 1089  [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1090  [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1091                                    NaN            NaN
# 1092  [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1093                                    NaN            NaN
# 1094  [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1095                                    NaN            NaN
# 1096  [12634px, 197.648px, 46.8203px, 15px]            2.0
#
#       exploded_highlight_node_order      top     left     width  height  \
# 1087                           29.0  12603.0  639.758  160.4840    15.0
# 1088                           30.0  12634.0  104.000   66.6484    15.0
# 1089                           31.0  12634.0  197.648   46.8203    15.0
# 1090                           32.0  12634.0  197.648   46.8203    15.0
# 1091                            NaN      NaN      NaN       NaN     NaN
# 1092                           32.0  12634.0  197.648   46.8203    15.0
# 1093                            NaN      NaN      NaN       NaN     NaN
# 1094                           32.0  12634.0  197.648   46.8203    15.0
# 1095                            NaN      NaN      NaN       NaN     NaN
# 1096                           32.0  12634.0  197.648   46.8203    15.0
#
#          _merge
# 1087       both
# 1088       both
# 1089       both
# 1090       both
# 1091  left_only
# 1092       both
# 1093  left_only
# 1094       both
# 1095  left_only
# 1096       both

# %%
merged.iloc[1087:1097]['xpaths'].tolist()
# Out:
# ['/html/body/document/type/sequence/filename/description/text/div[51]/p[6]/b/font',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/font[1]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[1]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[2]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[3]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[4]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]']

# %%
merged.iloc[1087:1097]['highlighted_xpaths'].tolist()
# Out:
# ['/html/body/document/type/sequence/filename/description/text/div[51]/p[6]/b/font',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/font[1]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[1]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  nan,
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  nan,
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  nan,
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]']

# %%
merged['is_outside'] = merged['_merge'].apply(lambda x: 1 if x=='left_only' else 0)

# %%
merged.to_csv("drop_check.csv")

# %%
#merged[merged['is_outside'] < 1].to_csv('merged_test.csv')

# %%
merged[merged['is_outside'] < 1]
# Out:
#                                                  xpaths  \
# 380   /html/body/document/type/sequence/filename/des...
# 405   /html/body/document/type/sequence/filename/des...
# 406   /html/body/document/type/sequence/filename/des...
# 407   /html/body/document/type/sequence/filename/des...
# 408   /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1369  /html/body/document/type/sequence/filename/des...
# 1371  /html/body/document/type/sequence/filename/des...
# 1372  /html/body/document/type/sequence/filename/des...
# 1373  /html/body/document/type/sequence/filename/des...
# 1374  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 380                        AGREEMENT AND PLAN OF MERGER                 380
# 405                                           ARTICLE I                 405
# 406                                         DEFINITIONS                 406
# 407                                        Section 1.01                 407
# 408                                         Definitions                 408
# ...                                                 ...                 ...
# 1369                                         (including                1369
# 1371                                                 ).                1371
# 1372                                       Section 2.12                1372
# 1373                                 Further Assurances                1373
# 1374  .  At and after the Second Effective Time, the...                1374
#
#                                      highlighted_xpaths  \
# 380   /html/body/document/type/sequence/filename/des...
# 405   /html/body/document/type/sequence/filename/des...
# 406   /html/body/document/type/sequence/filename/des...
# 407   /html/body/document/type/sequence/filename/des...
# 408   /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1369  /html/body/document/type/sequence/filename/des...
# 1371  /html/body/document/type/sequence/filename/des...
# 1372  /html/body/document/type/sequence/filename/des...
# 1373  /html/body/document/type/sequence/filename/des...
# 1374  /html/body/document/type/sequence/filename/des...
#
#         highlighted_segmented_text highlighted_labels  \
# 380   AGREEMENT AND PLAN OF MERGER                  t
# 405                      ARTICLE I                 sn
# 406                    DEFINITIONS                 st
# 407                   Section 1.01                ssn
# 408                    Definitions                sst
# ...                            ...                ...
# 1369                             .                sst
# 1371                             .                sst
# 1372                  Section 2.12                ssn
# 1373            Further Assurances                sst
# 1374                             .                sst
#
#       segment_number_from_idx                  highlighted_coordinates  \
# 380                       0.0     [2832px, 598.539px, 242.922px, 15px]
# 405                       1.0   [3331.5px, 685.602px, 68.7969px, 15px]
# 406                       2.0   [3362.5px, 675.922px, 88.1562px, 15px]
# 407                       3.0       [3393.5px, 104px, 67.6484px, 15px]
# 408                       4.0   [3393.5px, 199.648px, 63.3203px, 15px]
# ...                       ...                                      ...
# 1369                     62.0  [15889.5px, 199.156px, 91.8047px, 15px]
# 1371                     62.0  [15889.5px, 199.156px, 91.8047px, 15px]
# 1372                     63.0        [15967px, 104px, 68.6484px, 15px]
# 1373                     64.0    [15967px, 199.648px, 105.883px, 15px]
# 1374                     64.0    [15967px, 199.648px, 105.883px, 15px]
#
#       num_entries_1  exploded_highlight_node_order      top     left  \
# 380             1.0                            0.0   2832.0  598.539
# 405             1.0                            1.0   3331.5  685.602
# 406             1.0                            2.0   3362.5  675.922
# 407             1.0                            3.0   3393.5  104.000
# 408             2.0                            4.0   3393.5  199.648
# ...             ...                            ...      ...      ...
# 1369            2.0                           71.0  15889.5  199.156
# 1371            2.0                           71.0  15889.5  199.156
# 1372            1.0                           72.0  15967.0  104.000
# 1373            2.0                           73.0  15967.0  199.648
# 1374            2.0                           74.0  15967.0  199.648
#
#          width  height _merge  is_outside
# 380   242.9220    15.0   both           0
# 405    68.7969    15.0   both           0
# 406    88.1562    15.0   both           0
# 407    67.6484    15.0   both           0
# 408    63.3203    15.0   both           0
# ...        ...     ...    ...         ...
# 1369   91.8047    15.0   both           0
# 1371   91.8047    15.0   both           0
# 1372   68.6484    15.0   both           0
# 1373  105.8830    15.0   both           0
# 1374  105.8830    15.0   both           0
#
# [88 rows x 16 columns]

# %%
def assert_node_ordering_for_merged_table(merged: pd.DataFrame) -> pd.DataFrame:
    '''
    Due to repeat xpaths in both left and right table in merged, need to remove the duplicated rows
    '''
    drop_indices = []
    last_highlight_node_idx = -1
    for i, row in merged[merged['is_outside'] < 1].iterrows():
        if row.exploded_highlight_node_order and row.exploded_highlight_node_order != last_highlight_node_idx + 1:
            drop_indices.append(i)
        else:
            last_highlight_node_idx = row.exploded_highlight_node_order
    merged = merged.drop(drop_indices).reset_index(drop=True)
    
    # Assert both orderings keep their original structure
    assert merged.all_nodes_ordering.is_monotonic_increasing
    assert merged[merged['is_outside'] < 1].exploded_highlight_node_order.is_monotonic_increasing
    
    return merged, drop_indices

# %%
merged_ordered, drop_indices = assert_node_ordering_for_merged_table(merged)
empty_xpath_index = merged_ordered.fillna(0).where(merged_ordered['xpaths'] == '').dropna().index
empty_xpath_index
# Out:
# Int64Index([  17,  128,  256,  374,  379,  401,  429,  452,  480,  504,
#             ...
#             3110, 3129, 3179, 3219, 3259, 3274, 3307, 3327, 3348, 3356],
#            dtype='int64', length=123)

# %% [markdown]
# Why am I losing rows (1 row now) from the left table?

# %%
merged.iloc[drop_indices]
# Out:
#                                                  xpaths  \
# 1092  /html/body/document/type/sequence/filename/des...
# 1094  /html/body/document/type/sequence/filename/des...
# 1096  /html/body/document/type/sequence/filename/des...
# 1281  /html/body/document/type/sequence/filename/des...
# 1283  /html/body/document/type/sequence/filename/des...
# 1285  /html/body/document/type/sequence/filename/des...
# 1287  /html/body/document/type/sequence/filename/des...
# 1289  /html/body/document/type/sequence/filename/des...
# 1291  /html/body/document/type/sequence/filename/des...
# 1354  /html/body/document/type/sequence/filename/des...
# 1356  /html/body/document/type/sequence/filename/des...
# 1369  /html/body/document/type/sequence/filename/des...
# 1371  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 1092  ”) shall take place in New York City at the of...                1092
# 1094      ”) after the date the conditions set forth in                1094
# 1096  (other than conditions that by their nature ar...                1096
# 1281  ” and, such shares of Company Common Stock, the “                1281
# 1283  ”), shall not be converted into or be exchange...                1283
# 1285  (and cash in lieu of any fractional Parent ADS...                1285
# 1287                                                and                1287
# 1289  ), without interest, and immediately following...                1289
# 1291  to pay for shares of Company Common Stock for ...                1291
# 1354                                                 or                1354
# 1356  , if, during the period between the date of th...                1356
# 1369                                         (including                1369
# 1371                                                 ).                1371
#
#                                      highlighted_xpaths  \
# 1092  /html/body/document/type/sequence/filename/des...
# 1094  /html/body/document/type/sequence/filename/des...
# 1096  /html/body/document/type/sequence/filename/des...
# 1281  /html/body/document/type/sequence/filename/des...
# 1283  /html/body/document/type/sequence/filename/des...
# 1285  /html/body/document/type/sequence/filename/des...
# 1287  /html/body/document/type/sequence/filename/des...
# 1289  /html/body/document/type/sequence/filename/des...
# 1291  /html/body/document/type/sequence/filename/des...
# 1354  /html/body/document/type/sequence/filename/des...
# 1356  /html/body/document/type/sequence/filename/des...
# 1369  /html/body/document/type/sequence/filename/des...
# 1371  /html/body/document/type/sequence/filename/des...
#
#      highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 1092                          .                sst                     30.0
# 1094                          .                sst                     30.0
# 1096                          .                sst                     30.0
# 1281                          .                sst                     48.0
# 1283                          .                sst                     48.0
# 1285                          .                sst                     48.0
# 1287                          .                sst                     48.0
# 1289                          .                sst                     48.0
# 1291                          .                sst                     48.0
# 1354                          .                sst                     55.0
# 1356                          .                sst                     55.0
# 1369                          .                sst                     62.0
# 1371                          .                sst                     62.0
#
#                       highlighted_coordinates  num_entries_1  \
# 1092    [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1094    [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1096    [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1281    [14639px, 199.648px, 99.2344px, 15px]            2.0
# 1283    [14639px, 199.648px, 99.2344px, 15px]            2.0
# 1285    [14639px, 199.648px, 99.2344px, 15px]            2.0
# 1287    [14639px, 199.648px, 99.2344px, 15px]            2.0
# 1289    [14639px, 199.648px, 99.2344px, 15px]            2.0
# 1291    [14639px, 199.648px, 99.2344px, 15px]            2.0
# 1354    [15638px, 199.648px, 70.7344px, 15px]            2.0
# 1356    [15638px, 199.648px, 70.7344px, 15px]            2.0
# 1369  [15889.5px, 199.156px, 91.8047px, 15px]            2.0
# 1371  [15889.5px, 199.156px, 91.8047px, 15px]            2.0
#
#       exploded_highlight_node_order      top     left    width  height _merge  \
# 1092                           32.0  12634.0  197.648  46.8203    15.0   both
# 1094                           32.0  12634.0  197.648  46.8203    15.0   both
# 1096                           32.0  12634.0  197.648  46.8203    15.0   both
# 1281                           53.0  14639.0  199.648  99.2344    15.0   both
# 1283                           53.0  14639.0  199.648  99.2344    15.0   both
# 1285                           53.0  14639.0  199.648  99.2344    15.0   both
# 1287                           53.0  14639.0  199.648  99.2344    15.0   both
# 1289                           53.0  14639.0  199.648  99.2344    15.0   both
# 1291                           53.0  14639.0  199.648  99.2344    15.0   both
# 1354                           61.0  15638.0  199.648  70.7344    15.0   both
# 1356                           61.0  15638.0  199.648  70.7344    15.0   both
# 1369                           71.0  15889.5  199.156  91.8047    15.0   both
# 1371                           71.0  15889.5  199.156  91.8047    15.0   both
#
#       is_outside
# 1092           0
# 1094           0
# 1096           0
# 1281           0
# 1283           0
# 1285           0
# 1287           0
# 1289           0
# 1291           0
# 1354           0
# 1356           0
# 1369           0
# 1371           0

# %%
merged_ordered[merged_ordered['all_nodes_ordering'] == merged_ordered.index]
# Out:
#                                                  xpaths  \
# 0                              /html/body/document/type
# 1                     /html/body/document/type/sequence
# 2            /html/body/document/type/sequence/filename
# 3     /html/body/document/type/sequence/filename/des...
# 4     /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1087  /html/body/document/type/sequence/filename/des...
# 1088  /html/body/document/type/sequence/filename/des...
# 1089  /html/body/document/type/sequence/filename/des...
# 1090  /html/body/document/type/sequence/filename/des...
# 1091  /html/body/document/type/sequence/filename/des...
#
#                                       text  all_nodes_ordering  \
# 0                                   EX-4.7                   0
# 1                                        3                   1
# 2                      a21-3954_1ex4d7.htm                   2
# 3                                   EX-4.7                   3
# 4        bazadebezolkohpepadr="1723055342"                   4
# ...                                    ...                 ...
# 1087                   CLOSING; THE MERGER                1087
# 1088                          Section 2.01                1088
# 1089                               Closing                1089
# 1090  .  The closing of the Mergers (the “                1090
# 1091                               Closing                1091
#
#                                      highlighted_xpaths  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1087  /html/body/document/type/sequence/filename/des...
# 1088  /html/body/document/type/sequence/filename/des...
# 1089  /html/body/document/type/sequence/filename/des...
# 1090  /html/body/document/type/sequence/filename/des...
# 1091                                                NaN
#
#      highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 0                           NaN                NaN                      NaN
# 1                           NaN                NaN                      NaN
# 2                           NaN                NaN                      NaN
# 3                           NaN                NaN                      NaN
# 4                           NaN                NaN                      NaN
# ...                         ...                ...                      ...
# 1087        CLOSING; THE MERGER                 st                     28.0
# 1088               Section 2.01                ssn                     29.0
# 1089                    Closing                sst                     30.0
# 1090                          .                sst                     30.0
# 1091                        NaN                NaN                      NaN
#
#                     highlighted_coordinates  num_entries_1  \
# 0                                       NaN            NaN
# 1                                       NaN            NaN
# 2                                       NaN            NaN
# 3                                       NaN            NaN
# 4                                       NaN            NaN
# ...                                     ...            ...
# 1087  [12603px, 639.758px, 160.484px, 15px]            1.0
# 1088      [12634px, 104px, 66.6484px, 15px]            1.0
# 1089  [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1090  [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1091                                    NaN            NaN
#
#       exploded_highlight_node_order      top     left     width  height  \
# 0                               NaN      NaN      NaN       NaN     NaN
# 1                               NaN      NaN      NaN       NaN     NaN
# 2                               NaN      NaN      NaN       NaN     NaN
# 3                               NaN      NaN      NaN       NaN     NaN
# 4                               NaN      NaN      NaN       NaN     NaN
# ...                             ...      ...      ...       ...     ...
# 1087                           29.0  12603.0  639.758  160.4840    15.0
# 1088                           30.0  12634.0  104.000   66.6484    15.0
# 1089                           31.0  12634.0  197.648   46.8203    15.0
# 1090                           32.0  12634.0  197.648   46.8203    15.0
# 1091                            NaN      NaN      NaN       NaN     NaN
#
#          _merge  is_outside
# 0     left_only           1
# 1     left_only           1
# 2     left_only           1
# 3     left_only           1
# 4     left_only           1
# ...         ...         ...
# 1087       both           0
# 1088       both           0
# 1089       both           0
# 1090       both           0
# 1091  left_only           1
#
# [1092 rows x 16 columns]

# %%
merged_ordered[merged_ordered['all_nodes_ordering'] > merged_ordered.index]
# Out:
#                                                  xpaths  \
# 1092  /html/body/document/type/sequence/filename/des...
# 1093  /html/body/document/type/sequence/filename/des...
# 1094  /html/body/document/type/sequence/filename/des...
# 1095
# 1096  /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 3353  /html/body/document/type/sequence/filename/des...
# 3354  /html/body/document/type/sequence/filename/des...
# 3355  /html/body/document/type/sequence/filename/des...
# 3356
# 3357  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 1092                           Prospective Closing Date                1093
# 1093                                         Article IX                1095
# 1094                                                 21                1097
# 1095  SEQ.=1,FOLIO='21',FILE='C:\JMS\105568\21-3954-...                1098
# 1096  to the extent permitted by Applicable Law, wai...                1099
# ...                                                 ...                 ...
# 3353                                                  [                3366
# 3354                 Signature Page to Merger Agreement                3367
# 3355                                                  ]                3368
# 3356  SEQ.=1,FOLIO='',FILE='C:\JMS\120448\21-3954-1\...                3369
# 3357  <img src="https://www.sec.gov/akam/13/pixel_66...                3370
#
#                                      highlighted_xpaths  \
# 1092                                                NaN
# 1093                                                NaN
# 1094  /html/body/document/type/sequence/filename/des...
# 1095                                                NaN
# 1096                                                NaN
# ...                                                 ...
# 3353                                                NaN
# 3354                                                NaN
# 3355                                                NaN
# 3356                                                NaN
# 3357                                                NaN
#
#      highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 1092                        NaN                NaN                      NaN
# 1093                        NaN                NaN                      NaN
# 1094                         21                  n                     31.0
# 1095                        NaN                NaN                      NaN
# 1096                        NaN                NaN                      NaN
# ...                         ...                ...                      ...
# 3353                        NaN                NaN                      NaN
# 3354                        NaN                NaN                      NaN
# 3355                        NaN                NaN                      NaN
# 3356                        NaN                NaN                      NaN
# 3357                        NaN                NaN                      NaN
#
#                       highlighted_coordinates  num_entries_1  \
# 1092                                      NaN            NaN
# 1093                                      NaN            NaN
# 1094  [12680.5px, 713.328px, 13.3359px, 15px]            1.0
# 1095                                      NaN            NaN
# 1096                                      NaN            NaN
# ...                                       ...            ...
# 3353                                      NaN            NaN
# 3354                                      NaN            NaN
# 3355                                      NaN            NaN
# 3356                                      NaN            NaN
# 3357                                      NaN            NaN
#
#       exploded_highlight_node_order      top     left    width  height  \
# 1092                            NaN      NaN      NaN      NaN     NaN
# 1093                            NaN      NaN      NaN      NaN     NaN
# 1094                           33.0  12680.5  713.328  13.3359    15.0
# 1095                            NaN      NaN      NaN      NaN     NaN
# 1096                            NaN      NaN      NaN      NaN     NaN
# ...                             ...      ...      ...      ...     ...
# 3353                            NaN      NaN      NaN      NaN     NaN
# 3354                            NaN      NaN      NaN      NaN     NaN
# 3355                            NaN      NaN      NaN      NaN     NaN
# 3356                            NaN      NaN      NaN      NaN     NaN
# 3357                            NaN      NaN      NaN      NaN     NaN
#
#          _merge  is_outside
# 1092  left_only           1
# 1093  left_only           1
# 1094       both           0
# 1095  left_only           1
# 1096  left_only           1
# ...         ...         ...
# 3353  left_only           1
# 3354  left_only           1
# 3355  left_only           1
# 3356  left_only           1
# 3357  left_only           1
#
# [2266 rows x 16 columns]

# %%
merged_ordered[1087:1097]['xpaths'].tolist()
# Out:
# ['/html/body/document/type/sequence/filename/description/text/div[51]/p[6]/b/font',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/font[1]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[1]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[2]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[3]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[8]/u[4]',
#  '/html/body/document/type/sequence/filename/description/text/div[51]/p[10]',
#  '',
#  '/html/body/document/type/sequence/filename/description/text/div[53]/p[2]/font']

# %%
merged_ordered[1087:1097]
# Out:
#                                                  xpaths  \
# 1087  /html/body/document/type/sequence/filename/des...
# 1088  /html/body/document/type/sequence/filename/des...
# 1089  /html/body/document/type/sequence/filename/des...
# 1090  /html/body/document/type/sequence/filename/des...
# 1091  /html/body/document/type/sequence/filename/des...
# 1092  /html/body/document/type/sequence/filename/des...
# 1093  /html/body/document/type/sequence/filename/des...
# 1094  /html/body/document/type/sequence/filename/des...
# 1095
# 1096  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 1087                                CLOSING; THE MERGER                1087
# 1088                                       Section 2.01                1088
# 1089                                            Closing                1089
# 1090               .  The closing of the Mergers (the “                1090
# 1091                                            Closing                1091
# 1092                           Prospective Closing Date                1093
# 1093                                         Article IX                1095
# 1094                                                 21                1097
# 1095  SEQ.=1,FOLIO='21',FILE='C:\JMS\105568\21-3954-...                1098
# 1096  to the extent permitted by Applicable Law, wai...                1099
#
#                                      highlighted_xpaths  \
# 1087  /html/body/document/type/sequence/filename/des...
# 1088  /html/body/document/type/sequence/filename/des...
# 1089  /html/body/document/type/sequence/filename/des...
# 1090  /html/body/document/type/sequence/filename/des...
# 1091                                                NaN
# 1092                                                NaN
# 1093                                                NaN
# 1094  /html/body/document/type/sequence/filename/des...
# 1095                                                NaN
# 1096                                                NaN
#
#      highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 1087        CLOSING; THE MERGER                 st                     28.0
# 1088               Section 2.01                ssn                     29.0
# 1089                    Closing                sst                     30.0
# 1090                          .                sst                     30.0
# 1091                        NaN                NaN                      NaN
# 1092                        NaN                NaN                      NaN
# 1093                        NaN                NaN                      NaN
# 1094                         21                  n                     31.0
# 1095                        NaN                NaN                      NaN
# 1096                        NaN                NaN                      NaN
#
#                       highlighted_coordinates  num_entries_1  \
# 1087    [12603px, 639.758px, 160.484px, 15px]            1.0
# 1088        [12634px, 104px, 66.6484px, 15px]            1.0
# 1089    [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1090    [12634px, 197.648px, 46.8203px, 15px]            2.0
# 1091                                      NaN            NaN
# 1092                                      NaN            NaN
# 1093                                      NaN            NaN
# 1094  [12680.5px, 713.328px, 13.3359px, 15px]            1.0
# 1095                                      NaN            NaN
# 1096                                      NaN            NaN
#
#       exploded_highlight_node_order      top     left     width  height  \
# 1087                           29.0  12603.0  639.758  160.4840    15.0
# 1088                           30.0  12634.0  104.000   66.6484    15.0
# 1089                           31.0  12634.0  197.648   46.8203    15.0
# 1090                           32.0  12634.0  197.648   46.8203    15.0
# 1091                            NaN      NaN      NaN       NaN     NaN
# 1092                            NaN      NaN      NaN       NaN     NaN
# 1093                            NaN      NaN      NaN       NaN     NaN
# 1094                           33.0  12680.5  713.328   13.3359    15.0
# 1095                            NaN      NaN      NaN       NaN     NaN
# 1096                            NaN      NaN      NaN       NaN     NaN
#
#          _merge  is_outside
# 1087       both           0
# 1088       both           0
# 1089       both           0
# 1090       both           0
# 1091  left_only           1
# 1092  left_only           1
# 1093  left_only           1
# 1094       both           0
# 1095  left_only           1
# 1096  left_only           1

# %% [markdown]
# Okay I see what happened. At index 737 for all nodes ordering, somehow the join had a double repeat. All examples of that node in the left dataframe were deleted since 2 highlight nodes before it matched with it. Not sure why tho?

# %% [markdown]
# The (c) node was already matched as well as what followed it but then it and one of the successors was matched again. I think there can be some kind of check to see if highlight node was already matched and if removing current row would destroy the all nodes order, just dont delete the row...
#
# Seems weird but maybe it would work.
#
# Maybe another method could be tracking the start coordinates of the text in each node and then somehow getting a stricter order on that...
#
# Or maybe tracking which char offset from node beginning a highlight belongs to. then if theres overlap in the inveral, we merge, if not we move on. do the same for the all nodes as well

# %% [markdown]
# Let's do the BIES tagging now

# %%
def tag_bies_for_highlights(merged: pd.DataFrame) -> pd.DataFrame:
    
    tags = []
    count = 1
    for i, row in merged.iterrows():
        list_entry_count = row.num_entries_1
        
        # Non highlighted row
        if math.isnan(list_entry_count):
            tags.append('o')
        
        # Single highlighted node
        elif list_entry_count == 1:
            tags.append(f's_{row.highlighted_labels}')
            count = 1
        
        # Last entry in group greater than size 1
        elif count == list_entry_count:
            tags.append(f'e_{row.highlighted_labels}')
            count = 1
        elif (count < list_entry_count) and count == 1:
            tags.append(f'b_{row.highlighted_labels}')
            count += 1
        elif (count < list_entry_count) and count > 1:
            tags.append(f'i_{row.highlighted_labels}')
            count += 1
    merged['tagged_sequence'] = tags
    return merged

# %%
merged_tagged = tag_bies_for_highlights(merged_ordered)
merged_tagged
# Out:
#                                                  xpaths  \
# 0                              /html/body/document/type
# 1                     /html/body/document/type/sequence
# 2            /html/body/document/type/sequence/filename
# 3     /html/body/document/type/sequence/filename/des...
# 4     /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 3353  /html/body/document/type/sequence/filename/des...
# 3354  /html/body/document/type/sequence/filename/des...
# 3355  /html/body/document/type/sequence/filename/des...
# 3356
# 3357  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 0                                                EX-4.7                   0
# 1                                                     3                   1
# 2                                   a21-3954_1ex4d7.htm                   2
# 3                                                EX-4.7                   3
# 4                     bazadebezolkohpepadr="1723055342"                   4
# ...                                                 ...                 ...
# 3353                                                  [                3366
# 3354                 Signature Page to Merger Agreement                3367
# 3355                                                  ]                3368
# 3356  SEQ.=1,FOLIO='',FILE='C:\JMS\120448\21-3954-1\...                3369
# 3357  <img src="https://www.sec.gov/akam/13/pixel_66...                3370
#
#      highlighted_xpaths highlighted_segmented_text highlighted_labels  \
# 0                   NaN                        NaN                NaN
# 1                   NaN                        NaN                NaN
# 2                   NaN                        NaN                NaN
# 3                   NaN                        NaN                NaN
# 4                   NaN                        NaN                NaN
# ...                 ...                        ...                ...
# 3353                NaN                        NaN                NaN
# 3354                NaN                        NaN                NaN
# 3355                NaN                        NaN                NaN
# 3356                NaN                        NaN                NaN
# 3357                NaN                        NaN                NaN
#
#       segment_number_from_idx highlighted_coordinates  num_entries_1  \
# 0                         NaN                     NaN            NaN
# 1                         NaN                     NaN            NaN
# 2                         NaN                     NaN            NaN
# 3                         NaN                     NaN            NaN
# 4                         NaN                     NaN            NaN
# ...                       ...                     ...            ...
# 3353                      NaN                     NaN            NaN
# 3354                      NaN                     NaN            NaN
# 3355                      NaN                     NaN            NaN
# 3356                      NaN                     NaN            NaN
# 3357                      NaN                     NaN            NaN
#
#       exploded_highlight_node_order  top  left  width  height     _merge  \
# 0                               NaN  NaN   NaN    NaN     NaN  left_only
# 1                               NaN  NaN   NaN    NaN     NaN  left_only
# 2                               NaN  NaN   NaN    NaN     NaN  left_only
# 3                               NaN  NaN   NaN    NaN     NaN  left_only
# 4                               NaN  NaN   NaN    NaN     NaN  left_only
# ...                             ...  ...   ...    ...     ...        ...
# 3353                            NaN  NaN   NaN    NaN     NaN  left_only
# 3354                            NaN  NaN   NaN    NaN     NaN  left_only
# 3355                            NaN  NaN   NaN    NaN     NaN  left_only
# 3356                            NaN  NaN   NaN    NaN     NaN  left_only
# 3357                            NaN  NaN   NaN    NaN     NaN  left_only
#
#       is_outside tagged_sequence
# 0              1               o
# 1              1               o
# 2              1               o
# 3              1               o
# 4              1               o
# ...          ...             ...
# 3353           1               o
# 3354           1               o
# 3355           1               o
# 3356           1               o
# 3357           1               o
#
# [3358 rows x 17 columns]

# %%
merged_tagged[merged_tagged['is_outside'] < 1]
# Out:
#                                                  xpaths  \
# 380   /html/body/document/type/sequence/filename/des...
# 405   /html/body/document/type/sequence/filename/des...
# 406   /html/body/document/type/sequence/filename/des...
# 407   /html/body/document/type/sequence/filename/des...
# 408   /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1355  /html/body/document/type/sequence/filename/des...
# 1356  /html/body/document/type/sequence/filename/des...
# 1359  /html/body/document/type/sequence/filename/des...
# 1360  /html/body/document/type/sequence/filename/des...
# 1361  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 380                        AGREEMENT AND PLAN OF MERGER                 380
# 405                                           ARTICLE I                 405
# 406                                         DEFINITIONS                 406
# 407                                        Section 1.01                 407
# 408                                         Definitions                 408
# ...                                                 ...                 ...
# 1355                                  Lost Certificates                1366
# 1356  .  If any Certificate shall have been lost, st...                1367
# 1359                                       Section 2.12                1372
# 1360                                 Further Assurances                1373
# 1361  .  At and after the Second Effective Time, the...                1374
#
#                                      highlighted_xpaths  \
# 380   /html/body/document/type/sequence/filename/des...
# 405   /html/body/document/type/sequence/filename/des...
# 406   /html/body/document/type/sequence/filename/des...
# 407   /html/body/document/type/sequence/filename/des...
# 408   /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1355  /html/body/document/type/sequence/filename/des...
# 1356  /html/body/document/type/sequence/filename/des...
# 1359  /html/body/document/type/sequence/filename/des...
# 1360  /html/body/document/type/sequence/filename/des...
# 1361  /html/body/document/type/sequence/filename/des...
#
#         highlighted_segmented_text highlighted_labels  \
# 380   AGREEMENT AND PLAN OF MERGER                  t
# 405                      ARTICLE I                 sn
# 406                    DEFINITIONS                 st
# 407                   Section 1.01                ssn
# 408                    Definitions                sst
# ...                            ...                ...
# 1355             Lost Certificates                sst
# 1356                             .                sst
# 1359                  Section 2.12                ssn
# 1360            Further Assurances                sst
# 1361                             .                sst
#
#       segment_number_from_idx                  highlighted_coordinates  \
# 380                       0.0     [2832px, 598.539px, 242.922px, 15px]
# 405                       1.0   [3331.5px, 685.602px, 68.7969px, 15px]
# 406                       2.0   [3362.5px, 675.922px, 88.1562px, 15px]
# 407                       3.0       [3393.5px, 104px, 67.6484px, 15px]
# 408                       4.0   [3393.5px, 199.648px, 63.3203px, 15px]
# ...                       ...                                      ...
# 1355                     62.0  [15889.5px, 199.156px, 91.8047px, 15px]
# 1356                     62.0  [15889.5px, 199.156px, 91.8047px, 15px]
# 1359                     63.0        [15967px, 104px, 68.6484px, 15px]
# 1360                     64.0    [15967px, 199.648px, 105.883px, 15px]
# 1361                     64.0    [15967px, 199.648px, 105.883px, 15px]
#
#       num_entries_1  exploded_highlight_node_order      top     left  \
# 380             1.0                            0.0   2832.0  598.539
# 405             1.0                            1.0   3331.5  685.602
# 406             1.0                            2.0   3362.5  675.922
# 407             1.0                            3.0   3393.5  104.000
# 408             2.0                            4.0   3393.5  199.648
# ...             ...                            ...      ...      ...
# 1355            2.0                           70.0  15889.5  199.156
# 1356            2.0                           71.0  15889.5  199.156
# 1359            1.0                           72.0  15967.0  104.000
# 1360            2.0                           73.0  15967.0  199.648
# 1361            2.0                           74.0  15967.0  199.648
#
#          width  height _merge  is_outside tagged_sequence
# 380   242.9220    15.0   both           0             s_t
# 405    68.7969    15.0   both           0            s_sn
# 406    88.1562    15.0   both           0            s_st
# 407    67.6484    15.0   both           0           s_ssn
# 408    63.3203    15.0   both           0           b_sst
# ...        ...     ...    ...         ...             ...
# 1355   91.8047    15.0   both           0           b_sst
# 1356   91.8047    15.0   both           0           e_sst
# 1359   68.6484    15.0   both           0           s_ssn
# 1360  105.8830    15.0   both           0           b_sst
# 1361  105.8830    15.0   both           0           e_sst
#
# [75 rows x 17 columns]

# %%
merged_tagged.to_csv('overlabeled_labeled.csv')

# %% [markdown]
# I think I need to modify this algorithm. The overlabeled file that I just tried somehow labeled index 245 as b_n but i think its a single highlight node? It looks like the master nodes might be traversing in a different order tbh not sure, I did label pretty wildly... but still not sure how that happens?

# %%
highlighted_df.iloc[2]
# Out:
# highlighted_xpaths            [/html/body/document/type/sequence/filename/de...
# highlighted_segmented_text                                        [DEFINITIONS]
# highlighted_labels                                                           st
# highlighted_coordinates                  [3362.5px, 675.922px, 88.1562px, 15px]
# segment_number_from_idx                                                       2
# num_entries_1                                                                 1
# num_entries_2                                                                 1
# Name: 2, dtype: object

# %%
highlighted_df.iloc[2]['highlighted_xpaths']
# Out:
# ['/html/body/document/type/sequence/filename/description/text/div[13]/p[10]/b/font']
