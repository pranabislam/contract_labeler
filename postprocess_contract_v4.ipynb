# %%
import json
import pandas as pd
import ast
import math

# %%
all_nodes_path = "C:/Users/islam/Downloads/all_contract_text.json"
highlighted_nodes_path = "C:/Users/islam/Downloads/contract_saved.json"
with open(all_nodes_path, encoding='UTF-8') as f:
    all_nodes_data = json.load(f)
with open(highlighted_nodes_path, encoding='UTF-8') as f:
    highlighted_data = json.load(f)

# %%
all_nodes_xpaths = ast.literal_eval(all_nodes_data['xpaths'])
all_nodes_segmented_text = ast.literal_eval(all_nodes_data['segmentedTexts'])
df = pd.DataFrame()
df['xpaths'] = all_nodes_xpaths
df['text'] = all_nodes_segmented_text
df['all_nodes_ordering'] = df.index.copy()

# %%
highlighted_data['c']
# Out:
# '[["84.3125px","543.5px","816px","175px"],["313.625px","880.391px","142.219px","15px"],["1730.12px","943.344px","16.2969px","15px"],["978.125px","945.203px","12.5938px","15px"],["1853.12px","917.906px","67.1719px","15px"],["2899.12px","943.719px","15.5469px","15px"],["2456.12px","880.406px","142.172px","15px"],["2424.12px","918.75px","65.4844px","15px"],["2488.12px","643.609px","106.656px","15px"],["2488.12px","616.938px","23.3281px","15px"],["3473.12px","943.719px","15.5469px","15px"],["4549.12px","943.719px","15.5469px","15px"],["4015.12px","943.719px","15.5469px","15px"],["5075.12px","943.719px","15.5469px","15px"],["8316.12px","909.094px","84.7969px","15px"],["8284.12px","918.75px","65.4844px","15px"],["8348.12px","643.609px","66.1562px","15px"],["8348.12px","616.938px","26.6719px","15px"],["8447.12px","940.391px","22.2188px","15px"],["8562.12px","635.078px","111.312px","15px"],["8562.12px","616.938px","14.7969px","15px"],["8490.12px","635.828px","109.219px","15px"],["8490.12px","616.938px","15.5469px","15px"],["8842.12px","918.75px","65.4844px","15px"],["8874.12px","813px","276.984px","15px"],["8906.12px","643.609px","129.219px","15px"],["8906.12px","616.938px","23.3281px","15px"],["9005.12px","940.391px","22.2188px","15px"]]'

# %%
highlight_xpaths = ast.literal_eval(highlighted_data['xpaths'])
highlight_segmented_text = ast.literal_eval(highlighted_data['segmentedTexts'])
highlight_text = ast.literal_eval(highlighted_data['texts'])
highlight_labels = ast.literal_eval(highlighted_data['labels'])
highlight_coordinates = ast.literal_eval(highlighted_data['c'])
highlighted_df = pd.DataFrame()
highlighted_df['highlighted_xpaths'] = highlight_xpaths
highlighted_df['highlighted_segmented_text'] = highlight_segmented_text
highlighted_df['highlighted_labels'] = highlight_labels
highlighted_df['highlighted_coordinates'] = highlight_coordinates
highlighted_df['segment_number_from_idx'] = highlighted_df.index.copy()
highlighted_df['num_entries_1'] = highlighted_df['highlighted_xpaths'].apply(len)
highlighted_df['num_entries_2'] = highlighted_df['highlighted_segmented_text'].apply(len)

# %%
assert highlighted_df['num_entries_1'].equals(highlighted_df['num_entries_2']), 'Mismatch in segmentation and groupings'
print("There is no mismatch in segmentations and groupings, we can proceed")
# Out:
# There is no mismatch in segmentations and groupings, we can proceed

# %%
exploded_highlight_df = highlighted_df[
    ['highlighted_xpaths','highlighted_segmented_text','highlighted_labels',
     'segment_number_from_idx','highlighted_coordinates','num_entries_1']
    ].explode(column=['highlighted_xpaths','highlighted_segmented_text']).reset_index(drop=True)

exploded_highlight_df['exploded_highlight_node_order'] = exploded_highlight_df.index.copy()

# %%
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# 5   /html/body/document/type/sequence/filename/des...
# 6   /html/body/document/type/sequence/filename/des...
# 7   /html/body/document/type/sequence/filename/des...
# 8   /html/body/document/type/sequence/filename/des...
# 9   /html/body/document/type/sequence/filename/des...
# 10  /html/body/document/type/sequence/filename/des...
# 11  /html/body/document/type/sequence/filename/des...
# 12  /html/body/document/type/sequence/filename/des...
# 13  /html/body/document/type/sequence/filename/des...
# 14  /html/body/document/type/sequence/filename/des...
# 15  /html/body/document/type/sequence/filename/des...
# 16  /html/body/document/type/sequence/filename/des...
# 17  /html/body/document/type/sequence/filename/des...
# 18  /html/body/document/type/sequence/filename/des...
# 19  /html/body/document/type/sequence/filename/des...
# 20  /html/body/document/type/sequence/filename/des...
# 21  /html/body/document/type/sequence/filename/des...
# 22  /html/body/document/type/sequence/filename/des...
# 23  /html/body/document/type/sequence/filename/des...
# 24  /html/body/document/type/sequence/filename/des...
# 25  /html/body/document/type/sequence/filename/des...
# 26  /html/body/document/type/sequence/filename/des...
# 27  /html/body/document/type/sequence/filename/des...
# 28  /html/body/document/type/sequence/filename/des...
# 29  /html/body/document/type/sequence/filename/des...
# 30  /html/body/document/type/sequence/filename/des...
# 31  /html/body/document/type/sequence/filename/des...
# 32  /html/body/document/type/sequence/filename/des...
# 33  /html/body/document/type/sequence/filename/des...
# 34  /html/body/document/type/sequence/filename/des...
# 35  /html/body/document/type/sequence/filename/des...
# 36  /html/body/document/type/sequence/filename/des...
# 37  /html/body/document/type/sequence/filename/des...
#
#              highlighted_segmented_text highlighted_labels  \
# 0          AGREEMENT AND PLAN OF MERGER                  t
# 1            dated as of March 22, 2021                  t
# 2                        by and between                  t
# 3             BANC OF\nCALIFORNIA, INC.                  t
# 4                                   and                  t
# 5            PACIFIC MERCANTILE BANCORP                  t
# 6                     TABLE OF CONTENTS                 st
# 7                                  -ii-                  n
# 8                                   -i-                  n
# 9                              RECITALS                 st
# 10                                  -2-                  n
# 11                  CERTAIN DEFINITIONS                 st
# 12                            ARTICLE 1                 sn
# 13                  Certain Definitions                sst
# 14                                    .                sst
# 15                                 1.01                ssn
# 16                                  -3-                  n
# 17                                  -5-                  n
# 18                                  -4-                  n
# 19                                  -6-                  n
# 20                           THE MERGER                 st
# 21                            ARTICLE 2                 sn
# 22                          The\nMerger                 st
# 23                                    .                 st
# 24                                 2.01                 sn
# 25                                 -12-                  n
# 26                 Effect of the Merger               ssst
# 27                                    .               ssst
# 28                                  (c)               sssn
# 29                   Charter and Bylaws               ssst
# 30                                    .               ssst
# 31                                  (b)               ssst
# 32                            ARTICLE 3                 sn
# 33  CONSIDERATION;\nEXCHANGE PROCEDURES                 st
# 34              Effect on Capital Stock                sst
# 35                                    .                sst
# 36                                 3.01                ssn
# 37                                 -13-                  n
#
#     segment_number_from_idx                  highlighted_coordinates  \
# 0                         0       [84.3125px, 543.5px, 816px, 175px]
# 1                         0       [84.3125px, 543.5px, 816px, 175px]
# 2                         0       [84.3125px, 543.5px, 816px, 175px]
# 3                         0       [84.3125px, 543.5px, 816px, 175px]
# 4                         0       [84.3125px, 543.5px, 816px, 175px]
# 5                         0       [84.3125px, 543.5px, 816px, 175px]
# 6                         1  [313.625px, 880.391px, 142.219px, 15px]
# 7                         2  [1730.12px, 943.344px, 16.2969px, 15px]
# 8                         3  [978.125px, 945.203px, 12.5938px, 15px]
# 9                         4  [1853.12px, 917.906px, 67.1719px, 15px]
# 10                        5  [2899.12px, 943.719px, 15.5469px, 15px]
# 11                        6  [2456.12px, 880.406px, 142.172px, 15px]
# 12                        7   [2424.12px, 918.75px, 65.4844px, 15px]
# 13                        8  [2488.12px, 643.609px, 106.656px, 15px]
# 14                        8  [2488.12px, 643.609px, 106.656px, 15px]
# 15                        9  [2488.12px, 616.938px, 23.3281px, 15px]
# 16                       10  [3473.12px, 943.719px, 15.5469px, 15px]
# 17                       11  [4549.12px, 943.719px, 15.5469px, 15px]
# 18                       12  [4015.12px, 943.719px, 15.5469px, 15px]
# 19                       13  [5075.12px, 943.719px, 15.5469px, 15px]
# 20                       14  [8316.12px, 909.094px, 84.7969px, 15px]
# 21                       15   [8284.12px, 918.75px, 65.4844px, 15px]
# 22                       16  [8348.12px, 643.609px, 66.1562px, 15px]
# 23                       16  [8348.12px, 643.609px, 66.1562px, 15px]
# 24                       17  [8348.12px, 616.938px, 26.6719px, 15px]
# 25                       18  [8447.12px, 940.391px, 22.2188px, 15px]
# 26                       19  [8562.12px, 635.078px, 111.312px, 15px]
# 27                       19  [8562.12px, 635.078px, 111.312px, 15px]
# 28                       20  [8562.12px, 616.938px, 14.7969px, 15px]
# 29                       21  [8490.12px, 635.828px, 109.219px, 15px]
# 30                       21  [8490.12px, 635.828px, 109.219px, 15px]
# 31                       22  [8490.12px, 616.938px, 15.5469px, 15px]
# 32                       23   [8842.12px, 918.75px, 65.4844px, 15px]
# 33                       24      [8874.12px, 813px, 276.984px, 15px]
# 34                       25  [8906.12px, 643.609px, 129.219px, 15px]
# 35                       25  [8906.12px, 643.609px, 129.219px, 15px]
# 36                       26  [8906.12px, 616.938px, 23.3281px, 15px]
# 37                       27  [9005.12px, 940.391px, 22.2188px, 15px]
#
#     num_entries_1  exploded_highlight_node_order
# 0               6                              0
# 1               6                              1
# 2               6                              2
# 3               6                              3
# 4               6                              4
# 5               6                              5
# 6               1                              6
# 7               1                              7
# 8               1                              8
# 9               1                              9
# 10              1                             10
# 11              1                             11
# 12              1                             12
# 13              2                             13
# 14              2                             14
# 15              1                             15
# 16              1                             16
# 17              1                             17
# 18              1                             18
# 19              1                             19
# 20              1                             20
# 21              1                             21
# 22              2                             22
# 23              2                             23
# 24              1                             24
# 25              1                             25
# 26              2                             26
# 27              2                             27
# 28              1                             28
# 29              2                             29
# 30              2                             30
# 31              1                             31
# 32              1                             32
# 33              1                             33
# 34              2                             34
# 35              2                             35
# 36              1                             36
# 37              1                             37

# %%
exploded_highlight_df['top'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[0][:-2]))
exploded_highlight_df['left'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[1][:-2]))
exploded_highlight_df['width'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[2][:-2]))
exploded_highlight_df['height'] = exploded_highlight_df['highlighted_coordinates'].apply(lambda x: float(x[3][:-2]))

# %%
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# 5   /html/body/document/type/sequence/filename/des...
# 6   /html/body/document/type/sequence/filename/des...
# 7   /html/body/document/type/sequence/filename/des...
# 8   /html/body/document/type/sequence/filename/des...
# 9   /html/body/document/type/sequence/filename/des...
# 10  /html/body/document/type/sequence/filename/des...
# 11  /html/body/document/type/sequence/filename/des...
# 12  /html/body/document/type/sequence/filename/des...
# 13  /html/body/document/type/sequence/filename/des...
# 14  /html/body/document/type/sequence/filename/des...
# 15  /html/body/document/type/sequence/filename/des...
# 16  /html/body/document/type/sequence/filename/des...
# 17  /html/body/document/type/sequence/filename/des...
# 18  /html/body/document/type/sequence/filename/des...
# 19  /html/body/document/type/sequence/filename/des...
# 20  /html/body/document/type/sequence/filename/des...
# 21  /html/body/document/type/sequence/filename/des...
# 22  /html/body/document/type/sequence/filename/des...
# 23  /html/body/document/type/sequence/filename/des...
# 24  /html/body/document/type/sequence/filename/des...
# 25  /html/body/document/type/sequence/filename/des...
# 26  /html/body/document/type/sequence/filename/des...
# 27  /html/body/document/type/sequence/filename/des...
# 28  /html/body/document/type/sequence/filename/des...
# 29  /html/body/document/type/sequence/filename/des...
# 30  /html/body/document/type/sequence/filename/des...
# 31  /html/body/document/type/sequence/filename/des...
# 32  /html/body/document/type/sequence/filename/des...
# 33  /html/body/document/type/sequence/filename/des...
# 34  /html/body/document/type/sequence/filename/des...
# 35  /html/body/document/type/sequence/filename/des...
# 36  /html/body/document/type/sequence/filename/des...
# 37  /html/body/document/type/sequence/filename/des...
#
#              highlighted_segmented_text highlighted_labels  \
# 0          AGREEMENT AND PLAN OF MERGER                  t
# 1            dated as of March 22, 2021                  t
# 2                        by and between                  t
# 3             BANC OF\nCALIFORNIA, INC.                  t
# 4                                   and                  t
# 5            PACIFIC MERCANTILE BANCORP                  t
# 6                     TABLE OF CONTENTS                 st
# 7                                  -ii-                  n
# 8                                   -i-                  n
# 9                              RECITALS                 st
# 10                                  -2-                  n
# 11                  CERTAIN DEFINITIONS                 st
# 12                            ARTICLE 1                 sn
# 13                  Certain Definitions                sst
# 14                                    .                sst
# 15                                 1.01                ssn
# 16                                  -3-                  n
# 17                                  -5-                  n
# 18                                  -4-                  n
# 19                                  -6-                  n
# 20                           THE MERGER                 st
# 21                            ARTICLE 2                 sn
# 22                          The\nMerger                 st
# 23                                    .                 st
# 24                                 2.01                 sn
# 25                                 -12-                  n
# 26                 Effect of the Merger               ssst
# 27                                    .               ssst
# 28                                  (c)               sssn
# 29                   Charter and Bylaws               ssst
# 30                                    .               ssst
# 31                                  (b)               ssst
# 32                            ARTICLE 3                 sn
# 33  CONSIDERATION;\nEXCHANGE PROCEDURES                 st
# 34              Effect on Capital Stock                sst
# 35                                    .                sst
# 36                                 3.01                ssn
# 37                                 -13-                  n
#
#     segment_number_from_idx                  highlighted_coordinates  \
# 0                         0       [84.3125px, 543.5px, 816px, 175px]
# 1                         0       [84.3125px, 543.5px, 816px, 175px]
# 2                         0       [84.3125px, 543.5px, 816px, 175px]
# 3                         0       [84.3125px, 543.5px, 816px, 175px]
# 4                         0       [84.3125px, 543.5px, 816px, 175px]
# 5                         0       [84.3125px, 543.5px, 816px, 175px]
# 6                         1  [313.625px, 880.391px, 142.219px, 15px]
# 7                         2  [1730.12px, 943.344px, 16.2969px, 15px]
# 8                         3  [978.125px, 945.203px, 12.5938px, 15px]
# 9                         4  [1853.12px, 917.906px, 67.1719px, 15px]
# 10                        5  [2899.12px, 943.719px, 15.5469px, 15px]
# 11                        6  [2456.12px, 880.406px, 142.172px, 15px]
# 12                        7   [2424.12px, 918.75px, 65.4844px, 15px]
# 13                        8  [2488.12px, 643.609px, 106.656px, 15px]
# 14                        8  [2488.12px, 643.609px, 106.656px, 15px]
# 15                        9  [2488.12px, 616.938px, 23.3281px, 15px]
# 16                       10  [3473.12px, 943.719px, 15.5469px, 15px]
# 17                       11  [4549.12px, 943.719px, 15.5469px, 15px]
# 18                       12  [4015.12px, 943.719px, 15.5469px, 15px]
# 19                       13  [5075.12px, 943.719px, 15.5469px, 15px]
# 20                       14  [8316.12px, 909.094px, 84.7969px, 15px]
# 21                       15   [8284.12px, 918.75px, 65.4844px, 15px]
# 22                       16  [8348.12px, 643.609px, 66.1562px, 15px]
# 23                       16  [8348.12px, 643.609px, 66.1562px, 15px]
# 24                       17  [8348.12px, 616.938px, 26.6719px, 15px]
# 25                       18  [8447.12px, 940.391px, 22.2188px, 15px]
# 26                       19  [8562.12px, 635.078px, 111.312px, 15px]
# 27                       19  [8562.12px, 635.078px, 111.312px, 15px]
# 28                       20  [8562.12px, 616.938px, 14.7969px, 15px]
# 29                       21  [8490.12px, 635.828px, 109.219px, 15px]
# 30                       21  [8490.12px, 635.828px, 109.219px, 15px]
# 31                       22  [8490.12px, 616.938px, 15.5469px, 15px]
# 32                       23   [8842.12px, 918.75px, 65.4844px, 15px]
# 33                       24      [8874.12px, 813px, 276.984px, 15px]
# 34                       25  [8906.12px, 643.609px, 129.219px, 15px]
# 35                       25  [8906.12px, 643.609px, 129.219px, 15px]
# 36                       26  [8906.12px, 616.938px, 23.3281px, 15px]
# 37                       27  [9005.12px, 940.391px, 22.2188px, 15px]
#
#     num_entries_1  exploded_highlight_node_order        top     left  \
# 0               6                              0    84.3125  543.500
# 1               6                              1    84.3125  543.500
# 2               6                              2    84.3125  543.500
# 3               6                              3    84.3125  543.500
# 4               6                              4    84.3125  543.500
# 5               6                              5    84.3125  543.500
# 6               1                              6   313.6250  880.391
# 7               1                              7  1730.1200  943.344
# 8               1                              8   978.1250  945.203
# 9               1                              9  1853.1200  917.906
# 10              1                             10  2899.1200  943.719
# 11              1                             11  2456.1200  880.406
# 12              1                             12  2424.1200  918.750
# 13              2                             13  2488.1200  643.609
# 14              2                             14  2488.1200  643.609
# 15              1                             15  2488.1200  616.938
# 16              1                             16  3473.1200  943.719
# 17              1                             17  4549.1200  943.719
# 18              1                             18  4015.1200  943.719
# 19              1                             19  5075.1200  943.719
# 20              1                             20  8316.1200  909.094
# 21              1                             21  8284.1200  918.750
# 22              2                             22  8348.1200  643.609
# 23              2                             23  8348.1200  643.609
# 24              1                             24  8348.1200  616.938
# 25              1                             25  8447.1200  940.391
# 26              2                             26  8562.1200  635.078
# 27              2                             27  8562.1200  635.078
# 28              1                             28  8562.1200  616.938
# 29              2                             29  8490.1200  635.828
# 30              2                             30  8490.1200  635.828
# 31              1                             31  8490.1200  616.938
# 32              1                             32  8842.1200  918.750
# 33              1                             33  8874.1200  813.000
# 34              2                             34  8906.1200  643.609
# 35              2                             35  8906.1200  643.609
# 36              1                             36  8906.1200  616.938
# 37              1                             37  9005.1200  940.391
#
#        width  height
# 0   816.0000   175.0
# 1   816.0000   175.0
# 2   816.0000   175.0
# 3   816.0000   175.0
# 4   816.0000   175.0
# 5   816.0000   175.0
# 6   142.2190    15.0
# 7    16.2969    15.0
# 8    12.5938    15.0
# 9    67.1719    15.0
# 10   15.5469    15.0
# 11  142.1720    15.0
# 12   65.4844    15.0
# 13  106.6560    15.0
# 14  106.6560    15.0
# 15   23.3281    15.0
# 16   15.5469    15.0
# 17   15.5469    15.0
# 18   15.5469    15.0
# 19   15.5469    15.0
# 20   84.7969    15.0
# 21   65.4844    15.0
# 22   66.1562    15.0
# 23   66.1562    15.0
# 24   26.6719    15.0
# 25   22.2188    15.0
# 26  111.3120    15.0
# 27  111.3120    15.0
# 28   14.7969    15.0
# 29  109.2190    15.0
# 30  109.2190    15.0
# 31   15.5469    15.0
# 32   65.4844    15.0
# 33  276.9840    15.0
# 34  129.2190    15.0
# 35  129.2190    15.0
# 36   23.3281    15.0
# 37   22.2188    15.0

# %% [markdown]
# Okay so far looks like we can do logic:
# 1. Sort by top and then if theres a tiebreaker, sort by left, and then sort by order in the highlight list (in the case of multiple nodes being highlighted in same row with 1 highlight box)
# 2. If it starts to show that top coordinates are not exact and are approximaate, we are going to need to start doing approximate sorting or some IOU related logic to post process this to infer if something is the same line (which seems extremely likely to work)

# %%
def sort_exploded_highlight_box_by_coordinates(exploded_highlight_df):
    '''
    If logic ever has to deal with approximations and some line inference (with IOU math),
    then this function will become more complicated but for now it seems okay
    '''
    return exploded_highlight_df.sort_values(by=['top','left','exploded_highlight_node_order']).reset_index(drop=True)

# %%
exploded_highlight_df = sort_exploded_highlight_box_by_coordinates(exploded_highlight_df)
exploded_highlight_df['exploded_highlight_node_order'] = exploded_highlight_df.index.copy()
exploded_highlight_df
# Out:
#                                    highlighted_xpaths  \
# 0   /html/body/document/type/sequence/filename/des...
# 1   /html/body/document/type/sequence/filename/des...
# 2   /html/body/document/type/sequence/filename/des...
# 3   /html/body/document/type/sequence/filename/des...
# 4   /html/body/document/type/sequence/filename/des...
# 5   /html/body/document/type/sequence/filename/des...
# 6   /html/body/document/type/sequence/filename/des...
# 7   /html/body/document/type/sequence/filename/des...
# 8   /html/body/document/type/sequence/filename/des...
# 9   /html/body/document/type/sequence/filename/des...
# 10  /html/body/document/type/sequence/filename/des...
# 11  /html/body/document/type/sequence/filename/des...
# 12  /html/body/document/type/sequence/filename/des...
# 13  /html/body/document/type/sequence/filename/des...
# 14  /html/body/document/type/sequence/filename/des...
# 15  /html/body/document/type/sequence/filename/des...
# 16  /html/body/document/type/sequence/filename/des...
# 17  /html/body/document/type/sequence/filename/des...
# 18  /html/body/document/type/sequence/filename/des...
# 19  /html/body/document/type/sequence/filename/des...
# 20  /html/body/document/type/sequence/filename/des...
# 21  /html/body/document/type/sequence/filename/des...
# 22  /html/body/document/type/sequence/filename/des...
# 23  /html/body/document/type/sequence/filename/des...
# 24  /html/body/document/type/sequence/filename/des...
# 25  /html/body/document/type/sequence/filename/des...
# 26  /html/body/document/type/sequence/filename/des...
# 27  /html/body/document/type/sequence/filename/des...
# 28  /html/body/document/type/sequence/filename/des...
# 29  /html/body/document/type/sequence/filename/des...
# 30  /html/body/document/type/sequence/filename/des...
# 31  /html/body/document/type/sequence/filename/des...
# 32  /html/body/document/type/sequence/filename/des...
# 33  /html/body/document/type/sequence/filename/des...
# 34  /html/body/document/type/sequence/filename/des...
# 35  /html/body/document/type/sequence/filename/des...
# 36  /html/body/document/type/sequence/filename/des...
# 37  /html/body/document/type/sequence/filename/des...
#
#              highlighted_segmented_text highlighted_labels  \
# 0          AGREEMENT AND PLAN OF MERGER                  t
# 1            dated as of March 22, 2021                  t
# 2                        by and between                  t
# 3             BANC OF\nCALIFORNIA, INC.                  t
# 4                                   and                  t
# 5            PACIFIC MERCANTILE BANCORP                  t
# 6                     TABLE OF CONTENTS                 st
# 7                                   -i-                  n
# 8                                  -ii-                  n
# 9                              RECITALS                 st
# 10                            ARTICLE 1                 sn
# 11                  CERTAIN DEFINITIONS                 st
# 12                                 1.01                ssn
# 13                  Certain Definitions                sst
# 14                                    .                sst
# 15                                  -2-                  n
# 16                                  -3-                  n
# 17                                  -4-                  n
# 18                                  -5-                  n
# 19                                  -6-                  n
# 20                            ARTICLE 2                 sn
# 21                           THE MERGER                 st
# 22                                 2.01                 sn
# 23                          The\nMerger                 st
# 24                                    .                 st
# 25                                 -12-                  n
# 26                                  (b)               ssst
# 27                   Charter and Bylaws               ssst
# 28                                    .               ssst
# 29                                  (c)               sssn
# 30                 Effect of the Merger               ssst
# 31                                    .               ssst
# 32                            ARTICLE 3                 sn
# 33  CONSIDERATION;\nEXCHANGE PROCEDURES                 st
# 34                                 3.01                ssn
# 35              Effect on Capital Stock                sst
# 36                                    .                sst
# 37                                 -13-                  n
#
#     segment_number_from_idx                  highlighted_coordinates  \
# 0                         0       [84.3125px, 543.5px, 816px, 175px]
# 1                         0       [84.3125px, 543.5px, 816px, 175px]
# 2                         0       [84.3125px, 543.5px, 816px, 175px]
# 3                         0       [84.3125px, 543.5px, 816px, 175px]
# 4                         0       [84.3125px, 543.5px, 816px, 175px]
# 5                         0       [84.3125px, 543.5px, 816px, 175px]
# 6                         1  [313.625px, 880.391px, 142.219px, 15px]
# 7                         3  [978.125px, 945.203px, 12.5938px, 15px]
# 8                         2  [1730.12px, 943.344px, 16.2969px, 15px]
# 9                         4  [1853.12px, 917.906px, 67.1719px, 15px]
# 10                        7   [2424.12px, 918.75px, 65.4844px, 15px]
# 11                        6  [2456.12px, 880.406px, 142.172px, 15px]
# 12                        9  [2488.12px, 616.938px, 23.3281px, 15px]
# 13                        8  [2488.12px, 643.609px, 106.656px, 15px]
# 14                        8  [2488.12px, 643.609px, 106.656px, 15px]
# 15                        5  [2899.12px, 943.719px, 15.5469px, 15px]
# 16                       10  [3473.12px, 943.719px, 15.5469px, 15px]
# 17                       12  [4015.12px, 943.719px, 15.5469px, 15px]
# 18                       11  [4549.12px, 943.719px, 15.5469px, 15px]
# 19                       13  [5075.12px, 943.719px, 15.5469px, 15px]
# 20                       15   [8284.12px, 918.75px, 65.4844px, 15px]
# 21                       14  [8316.12px, 909.094px, 84.7969px, 15px]
# 22                       17  [8348.12px, 616.938px, 26.6719px, 15px]
# 23                       16  [8348.12px, 643.609px, 66.1562px, 15px]
# 24                       16  [8348.12px, 643.609px, 66.1562px, 15px]
# 25                       18  [8447.12px, 940.391px, 22.2188px, 15px]
# 26                       22  [8490.12px, 616.938px, 15.5469px, 15px]
# 27                       21  [8490.12px, 635.828px, 109.219px, 15px]
# 28                       21  [8490.12px, 635.828px, 109.219px, 15px]
# 29                       20  [8562.12px, 616.938px, 14.7969px, 15px]
# 30                       19  [8562.12px, 635.078px, 111.312px, 15px]
# 31                       19  [8562.12px, 635.078px, 111.312px, 15px]
# 32                       23   [8842.12px, 918.75px, 65.4844px, 15px]
# 33                       24      [8874.12px, 813px, 276.984px, 15px]
# 34                       26  [8906.12px, 616.938px, 23.3281px, 15px]
# 35                       25  [8906.12px, 643.609px, 129.219px, 15px]
# 36                       25  [8906.12px, 643.609px, 129.219px, 15px]
# 37                       27  [9005.12px, 940.391px, 22.2188px, 15px]
#
#     num_entries_1  exploded_highlight_node_order        top     left  \
# 0               6                              0    84.3125  543.500
# 1               6                              1    84.3125  543.500
# 2               6                              2    84.3125  543.500
# 3               6                              3    84.3125  543.500
# 4               6                              4    84.3125  543.500
# 5               6                              5    84.3125  543.500
# 6               1                              6   313.6250  880.391
# 7               1                              7   978.1250  945.203
# 8               1                              8  1730.1200  943.344
# 9               1                              9  1853.1200  917.906
# 10              1                             10  2424.1200  918.750
# 11              1                             11  2456.1200  880.406
# 12              1                             12  2488.1200  616.938
# 13              2                             13  2488.1200  643.609
# 14              2                             14  2488.1200  643.609
# 15              1                             15  2899.1200  943.719
# 16              1                             16  3473.1200  943.719
# 17              1                             17  4015.1200  943.719
# 18              1                             18  4549.1200  943.719
# 19              1                             19  5075.1200  943.719
# 20              1                             20  8284.1200  918.750
# 21              1                             21  8316.1200  909.094
# 22              1                             22  8348.1200  616.938
# 23              2                             23  8348.1200  643.609
# 24              2                             24  8348.1200  643.609
# 25              1                             25  8447.1200  940.391
# 26              1                             26  8490.1200  616.938
# 27              2                             27  8490.1200  635.828
# 28              2                             28  8490.1200  635.828
# 29              1                             29  8562.1200  616.938
# 30              2                             30  8562.1200  635.078
# 31              2                             31  8562.1200  635.078
# 32              1                             32  8842.1200  918.750
# 33              1                             33  8874.1200  813.000
# 34              1                             34  8906.1200  616.938
# 35              2                             35  8906.1200  643.609
# 36              2                             36  8906.1200  643.609
# 37              1                             37  9005.1200  940.391
#
#        width  height
# 0   816.0000   175.0
# 1   816.0000   175.0
# 2   816.0000   175.0
# 3   816.0000   175.0
# 4   816.0000   175.0
# 5   816.0000   175.0
# 6   142.2190    15.0
# 7    12.5938    15.0
# 8    16.2969    15.0
# 9    67.1719    15.0
# 10   65.4844    15.0
# 11  142.1720    15.0
# 12   23.3281    15.0
# 13  106.6560    15.0
# 14  106.6560    15.0
# 15   15.5469    15.0
# 16   15.5469    15.0
# 17   15.5469    15.0
# 18   15.5469    15.0
# 19   15.5469    15.0
# 20   65.4844    15.0
# 21   84.7969    15.0
# 22   26.6719    15.0
# 23   66.1562    15.0
# 24   66.1562    15.0
# 25   22.2188    15.0
# 26   15.5469    15.0
# 27  109.2190    15.0
# 28  109.2190    15.0
# 29   14.7969    15.0
# 30  111.3120    15.0
# 31  111.3120    15.0
# 32   65.4844    15.0
# 33  276.9840    15.0
# 34   23.3281    15.0
# 35  129.2190    15.0
# 36  129.2190    15.0
# 37   22.2188    15.0

# %%
len(df)
# Out:
# 1781

# %%
merged = pd.merge(df, exploded_highlight_df, left_on='xpaths', right_on='highlighted_xpaths', how='left', indicator=True)
merged
# Out:
#                                                  xpaths  \
# 0                              /html/body/document/type
# 1                     /html/body/document/type/sequence
# 2            /html/body/document/type/sequence/filename
# 3     /html/body/document/type/sequence/filename/des...
# 4     /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1787  /html/body/document/type/sequence/filename/des...
# 1788  /html/body/document/type/sequence/filename/des...
# 1789  /html/body/document/type/sequence/filename/des...
# 1790  /html/body/document/type/sequence/filename/des...
# 1791  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 0                                                EX-2.1                   0
# 1                                                     2                   1
# 2                                       d35268dex21.htm                   2
# 3                                                EX-2.1                   3
# 4     EX-2.1 | https://www.sec.gov/Archives/edgar/da...                   4
# ...                                                 ...                 ...
# 1787                         PACIFIC MERCANTILE BANCORP                1776
# 1788                                                By:                1777
# 1789                                /s/ Denis Kalscheur                1778
# 1790                              Name: Denis Kalscheur                1779
# 1791                                    Title: Chairman                1780
#
#      highlighted_xpaths highlighted_segmented_text highlighted_labels  \
# 0                   NaN                        NaN                NaN
# 1                   NaN                        NaN                NaN
# 2                   NaN                        NaN                NaN
# 3                   NaN                        NaN                NaN
# 4                   NaN                        NaN                NaN
# ...                 ...                        ...                ...
# 1787                NaN                        NaN                NaN
# 1788                NaN                        NaN                NaN
# 1789                NaN                        NaN                NaN
# 1790                NaN                        NaN                NaN
# 1791                NaN                        NaN                NaN
#
#       segment_number_from_idx highlighted_coordinates  num_entries_1  \
# 0                         NaN                     NaN            NaN
# 1                         NaN                     NaN            NaN
# 2                         NaN                     NaN            NaN
# 3                         NaN                     NaN            NaN
# 4                         NaN                     NaN            NaN
# ...                       ...                     ...            ...
# 1787                      NaN                     NaN            NaN
# 1788                      NaN                     NaN            NaN
# 1789                      NaN                     NaN            NaN
# 1790                      NaN                     NaN            NaN
# 1791                      NaN                     NaN            NaN
#
#       exploded_highlight_node_order  top  left  width  height     _merge
# 0                               NaN  NaN   NaN    NaN     NaN  left_only
# 1                               NaN  NaN   NaN    NaN     NaN  left_only
# 2                               NaN  NaN   NaN    NaN     NaN  left_only
# 3                               NaN  NaN   NaN    NaN     NaN  left_only
# 4                               NaN  NaN   NaN    NaN     NaN  left_only
# ...                             ...  ...   ...    ...     ...        ...
# 1787                            NaN  NaN   NaN    NaN     NaN  left_only
# 1788                            NaN  NaN   NaN    NaN     NaN  left_only
# 1789                            NaN  NaN   NaN    NaN     NaN  left_only
# 1790                            NaN  NaN   NaN    NaN     NaN  left_only
# 1791                            NaN  NaN   NaN    NaN     NaN  left_only
#
# [1792 rows x 15 columns]

# %%
merged['is_outside'] = merged['_merge'].apply(lambda x: 1 if x=='left_only' else 0)

# %%
merged.to_csv("drop_check.csv")

# %%
#merged[merged['is_outside'] < 1].to_csv('merged_test.csv')

# %%
merged[merged['is_outside'] < 1]
# Out:
#                                                 xpaths  \
# 6    /html/body/document/type/sequence/filename/des...
# 7    /html/body/document/type/sequence/filename/des...
# 8    /html/body/document/type/sequence/filename/des...
# 9    /html/body/document/type/sequence/filename/des...
# 10   /html/body/document/type/sequence/filename/des...
# 11   /html/body/document/type/sequence/filename/des...
# 12   /html/body/document/type/sequence/filename/des...
# 91   /html/body/document/type/sequence/filename/des...
# 190  /html/body/document/type/sequence/filename/des...
# 201  /html/body/document/type/sequence/filename/des...
# 232  /html/body/document/type/sequence/filename/des...
# 233  /html/body/document/type/sequence/filename/des...
# 234  /html/body/document/type/sequence/filename/des...
# 235  /html/body/document/type/sequence/filename/des...
# 236  /html/body/document/type/sequence/filename/des...
# 237  /html/body/document/type/sequence/filename/des...
# 238  /html/body/document/type/sequence/filename/des...
# 271  /html/body/document/type/sequence/filename/des...
# 338  /html/body/document/type/sequence/filename/des...
# 372  /html/body/document/type/sequence/filename/des...
# 416  /html/body/document/type/sequence/filename/des...
# 473  /html/body/document/type/sequence/filename/des...
# 722  /html/body/document/type/sequence/filename/des...
# 723  /html/body/document/type/sequence/filename/des...
# 724  /html/body/document/type/sequence/filename/des...
# 725  /html/body/document/type/sequence/filename/des...
# 726  /html/body/document/type/sequence/filename/des...
# 727  /html/body/document/type/sequence/filename/des...
# 728  /html/body/document/type/sequence/filename/des...
# 733  /html/body/document/type/sequence/filename/des...
# 734  /html/body/document/type/sequence/filename/des...
# 735  /html/body/document/type/sequence/filename/des...
# 736  /html/body/document/type/sequence/filename/des...
# 737  /html/body/document/type/sequence/filename/des...
# 738  /html/body/document/type/sequence/filename/des...
# 739  /html/body/document/type/sequence/filename/des...
# 740  /html/body/document/type/sequence/filename/des...
# 741  /html/body/document/type/sequence/filename/des...
# 742  /html/body/document/type/sequence/filename/des...
# 743  /html/body/document/type/sequence/filename/des...
# 745  /html/body/document/type/sequence/filename/des...
# 746  /html/body/document/type/sequence/filename/des...
# 760  /html/body/document/type/sequence/filename/des...
# 761  /html/body/document/type/sequence/filename/des...
# 762  /html/body/document/type/sequence/filename/des...
# 763  /html/body/document/type/sequence/filename/des...
# 764  /html/body/document/type/sequence/filename/des...
# 765  /html/body/document/type/sequence/filename/des...
# 766  /html/body/document/type/sequence/filename/des...
# 778  /html/body/document/type/sequence/filename/des...
#
#                                                   text  all_nodes_ordering  \
# 6                         AGREEMENT AND PLAN OF MERGER                   6
# 7                           dated as of March 22, 2021                   7
# 8                                       by and between                   8
# 9                            BANC OF\nCALIFORNIA, INC.                   9
# 10                                                 and                  10
# 11                          PACIFIC MERCANTILE BANCORP                  11
# 12                                   TABLE OF CONTENTS                  12
# 91                                                 -i-                  91
# 190                                               -ii-                 190
# 201                                           RECITALS                 201
# 232                                          ARTICLE 1                 232
# 233                                CERTAIN DEFINITIONS                 233
# 234                                               1.01                 234
# 235                                               1.01                 234
# 236                                Certain Definitions                 235
# 237  . The following terms are used in this Agreeme...                 236
# 238  . The following terms are used in this Agreeme...                 236
# 271                                                -2-                 269
# 338                                                -3-                 336
# 372                                                -4-                 370
# 416                                                -5-                 414
# 473                                                -6-                 471
# 722                                          ARTICLE 2                 720
# 723                                         THE MERGER                 721
# 724                                               2.01                 722
# 725                                               2.01                 722
# 726                                        The\nMerger                 723
# 727                                                  .                 724
# 728                                                  .                 724
# 733                                               -12-                 729
# 734                                                (b)                 730
# 735                                                (b)                 730
# 736                                 Charter and Bylaws                 731
# 737  . The Charter and Bylaws of Parent as in effec...                 732
# 738  . The Charter and Bylaws of Parent as in effec...                 732
# 739                                                (c)                 733
# 740                                                (c)                 733
# 741                               Effect of the Merger                 734
# 742  . At the Effective Time, the effect of the Mer...                 735
# 743  . At the Effective Time, the effect of the Mer...                 735
# 745  of the MGCL and § 1107 of the CGCL, including ...                 737
# 746  of the MGCL and § 1107 of the CGCL, including ...                 737
# 760                                          ARTICLE 3                 751
# 761                CONSIDERATION;\nEXCHANGE PROCEDURES                 752
# 762                                               3.01                 753
# 763                                               3.01                 753
# 764                            Effect on Capital Stock                 754
# 765  . At the Effective Time, as a result of the Me...                 755
# 766  . At the Effective Time, as a result of the Me...                 755
# 778                                               -13-                 767
#
#                                     highlighted_xpaths  \
# 6    /html/body/document/type/sequence/filename/des...
# 7    /html/body/document/type/sequence/filename/des...
# 8    /html/body/document/type/sequence/filename/des...
# 9    /html/body/document/type/sequence/filename/des...
# 10   /html/body/document/type/sequence/filename/des...
# 11   /html/body/document/type/sequence/filename/des...
# 12   /html/body/document/type/sequence/filename/des...
# 91   /html/body/document/type/sequence/filename/des...
# 190  /html/body/document/type/sequence/filename/des...
# 201  /html/body/document/type/sequence/filename/des...
# 232  /html/body/document/type/sequence/filename/des...
# 233  /html/body/document/type/sequence/filename/des...
# 234  /html/body/document/type/sequence/filename/des...
# 235  /html/body/document/type/sequence/filename/des...
# 236  /html/body/document/type/sequence/filename/des...
# 237  /html/body/document/type/sequence/filename/des...
# 238  /html/body/document/type/sequence/filename/des...
# 271  /html/body/document/type/sequence/filename/des...
# 338  /html/body/document/type/sequence/filename/des...
# 372  /html/body/document/type/sequence/filename/des...
# 416  /html/body/document/type/sequence/filename/des...
# 473  /html/body/document/type/sequence/filename/des...
# 722  /html/body/document/type/sequence/filename/des...
# 723  /html/body/document/type/sequence/filename/des...
# 724  /html/body/document/type/sequence/filename/des...
# 725  /html/body/document/type/sequence/filename/des...
# 726  /html/body/document/type/sequence/filename/des...
# 727  /html/body/document/type/sequence/filename/des...
# 728  /html/body/document/type/sequence/filename/des...
# 733  /html/body/document/type/sequence/filename/des...
# 734  /html/body/document/type/sequence/filename/des...
# 735  /html/body/document/type/sequence/filename/des...
# 736  /html/body/document/type/sequence/filename/des...
# 737  /html/body/document/type/sequence/filename/des...
# 738  /html/body/document/type/sequence/filename/des...
# 739  /html/body/document/type/sequence/filename/des...
# 740  /html/body/document/type/sequence/filename/des...
# 741  /html/body/document/type/sequence/filename/des...
# 742  /html/body/document/type/sequence/filename/des...
# 743  /html/body/document/type/sequence/filename/des...
# 745  /html/body/document/type/sequence/filename/des...
# 746  /html/body/document/type/sequence/filename/des...
# 760  /html/body/document/type/sequence/filename/des...
# 761  /html/body/document/type/sequence/filename/des...
# 762  /html/body/document/type/sequence/filename/des...
# 763  /html/body/document/type/sequence/filename/des...
# 764  /html/body/document/type/sequence/filename/des...
# 765  /html/body/document/type/sequence/filename/des...
# 766  /html/body/document/type/sequence/filename/des...
# 778  /html/body/document/type/sequence/filename/des...
#
#               highlighted_segmented_text highlighted_labels  \
# 6           AGREEMENT AND PLAN OF MERGER                  t
# 7             dated as of March 22, 2021                  t
# 8                         by and between                  t
# 9              BANC OF\nCALIFORNIA, INC.                  t
# 10                                   and                  t
# 11            PACIFIC MERCANTILE BANCORP                  t
# 12                     TABLE OF CONTENTS                 st
# 91                                   -i-                  n
# 190                                 -ii-                  n
# 201                             RECITALS                 st
# 232                            ARTICLE 1                 sn
# 233                  CERTAIN DEFINITIONS                 st
# 234                                 1.01                ssn
# 235                                    .                sst
# 236                  Certain Definitions                sst
# 237                                 1.01                ssn
# 238                                    .                sst
# 271                                  -2-                  n
# 338                                  -3-                  n
# 372                                  -4-                  n
# 416                                  -5-                  n
# 473                                  -6-                  n
# 722                            ARTICLE 2                 sn
# 723                           THE MERGER                 st
# 724                                 2.01                 sn
# 725                                    .                 st
# 726                          The\nMerger                 st
# 727                                 2.01                 sn
# 728                                    .                 st
# 733                                 -12-                  n
# 734                                  (b)               ssst
# 735                                    .               ssst
# 736                   Charter and Bylaws               ssst
# 737                                  (b)               ssst
# 738                                    .               ssst
# 739                                  (c)               sssn
# 740                                    .               ssst
# 741                 Effect of the Merger               ssst
# 742                                  (c)               sssn
# 743                                    .               ssst
# 745                                  (c)               sssn
# 746                                    .               ssst
# 760                            ARTICLE 3                 sn
# 761  CONSIDERATION;\nEXCHANGE PROCEDURES                 st
# 762                                 3.01                ssn
# 763                                    .                sst
# 764              Effect on Capital Stock                sst
# 765                                 3.01                ssn
# 766                                    .                sst
# 778                                 -13-                  n
#
#      segment_number_from_idx                  highlighted_coordinates  \
# 6                        0.0       [84.3125px, 543.5px, 816px, 175px]
# 7                        0.0       [84.3125px, 543.5px, 816px, 175px]
# 8                        0.0       [84.3125px, 543.5px, 816px, 175px]
# 9                        0.0       [84.3125px, 543.5px, 816px, 175px]
# 10                       0.0       [84.3125px, 543.5px, 816px, 175px]
# 11                       0.0       [84.3125px, 543.5px, 816px, 175px]
# 12                       1.0  [313.625px, 880.391px, 142.219px, 15px]
# 91                       3.0  [978.125px, 945.203px, 12.5938px, 15px]
# 190                      2.0  [1730.12px, 943.344px, 16.2969px, 15px]
# 201                      4.0  [1853.12px, 917.906px, 67.1719px, 15px]
# 232                      7.0   [2424.12px, 918.75px, 65.4844px, 15px]
# 233                      6.0  [2456.12px, 880.406px, 142.172px, 15px]
# 234                      9.0  [2488.12px, 616.938px, 23.3281px, 15px]
# 235                      8.0  [2488.12px, 643.609px, 106.656px, 15px]
# 236                      8.0  [2488.12px, 643.609px, 106.656px, 15px]
# 237                      9.0  [2488.12px, 616.938px, 23.3281px, 15px]
# 238                      8.0  [2488.12px, 643.609px, 106.656px, 15px]
# 271                      5.0  [2899.12px, 943.719px, 15.5469px, 15px]
# 338                     10.0  [3473.12px, 943.719px, 15.5469px, 15px]
# 372                     12.0  [4015.12px, 943.719px, 15.5469px, 15px]
# 416                     11.0  [4549.12px, 943.719px, 15.5469px, 15px]
# 473                     13.0  [5075.12px, 943.719px, 15.5469px, 15px]
# 722                     15.0   [8284.12px, 918.75px, 65.4844px, 15px]
# 723                     14.0  [8316.12px, 909.094px, 84.7969px, 15px]
# 724                     17.0  [8348.12px, 616.938px, 26.6719px, 15px]
# 725                     16.0  [8348.12px, 643.609px, 66.1562px, 15px]
# 726                     16.0  [8348.12px, 643.609px, 66.1562px, 15px]
# 727                     17.0  [8348.12px, 616.938px, 26.6719px, 15px]
# 728                     16.0  [8348.12px, 643.609px, 66.1562px, 15px]
# 733                     18.0  [8447.12px, 940.391px, 22.2188px, 15px]
# 734                     22.0  [8490.12px, 616.938px, 15.5469px, 15px]
# 735                     21.0  [8490.12px, 635.828px, 109.219px, 15px]
# 736                     21.0  [8490.12px, 635.828px, 109.219px, 15px]
# 737                     22.0  [8490.12px, 616.938px, 15.5469px, 15px]
# 738                     21.0  [8490.12px, 635.828px, 109.219px, 15px]
# 739                     20.0  [8562.12px, 616.938px, 14.7969px, 15px]
# 740                     19.0  [8562.12px, 635.078px, 111.312px, 15px]
# 741                     19.0  [8562.12px, 635.078px, 111.312px, 15px]
# 742                     20.0  [8562.12px, 616.938px, 14.7969px, 15px]
# 743                     19.0  [8562.12px, 635.078px, 111.312px, 15px]
# 745                     20.0  [8562.12px, 616.938px, 14.7969px, 15px]
# 746                     19.0  [8562.12px, 635.078px, 111.312px, 15px]
# 760                     23.0   [8842.12px, 918.75px, 65.4844px, 15px]
# 761                     24.0      [8874.12px, 813px, 276.984px, 15px]
# 762                     26.0  [8906.12px, 616.938px, 23.3281px, 15px]
# 763                     25.0  [8906.12px, 643.609px, 129.219px, 15px]
# 764                     25.0  [8906.12px, 643.609px, 129.219px, 15px]
# 765                     26.0  [8906.12px, 616.938px, 23.3281px, 15px]
# 766                     25.0  [8906.12px, 643.609px, 129.219px, 15px]
# 778                     27.0  [9005.12px, 940.391px, 22.2188px, 15px]
#
#      num_entries_1  exploded_highlight_node_order        top     left  \
# 6              6.0                            0.0    84.3125  543.500
# 7              6.0                            1.0    84.3125  543.500
# 8              6.0                            2.0    84.3125  543.500
# 9              6.0                            3.0    84.3125  543.500
# 10             6.0                            4.0    84.3125  543.500
# 11             6.0                            5.0    84.3125  543.500
# 12             1.0                            6.0   313.6250  880.391
# 91             1.0                            7.0   978.1250  945.203
# 190            1.0                            8.0  1730.1200  943.344
# 201            1.0                            9.0  1853.1200  917.906
# 232            1.0                           10.0  2424.1200  918.750
# 233            1.0                           11.0  2456.1200  880.406
# 234            1.0                           12.0  2488.1200  616.938
# 235            2.0                           14.0  2488.1200  643.609
# 236            2.0                           13.0  2488.1200  643.609
# 237            1.0                           12.0  2488.1200  616.938
# 238            2.0                           14.0  2488.1200  643.609
# 271            1.0                           15.0  2899.1200  943.719
# 338            1.0                           16.0  3473.1200  943.719
# 372            1.0                           17.0  4015.1200  943.719
# 416            1.0                           18.0  4549.1200  943.719
# 473            1.0                           19.0  5075.1200  943.719
# 722            1.0                           20.0  8284.1200  918.750
# 723            1.0                           21.0  8316.1200  909.094
# 724            1.0                           22.0  8348.1200  616.938
# 725            2.0                           24.0  8348.1200  643.609
# 726            2.0                           23.0  8348.1200  643.609
# 727            1.0                           22.0  8348.1200  616.938
# 728            2.0                           24.0  8348.1200  643.609
# 733            1.0                           25.0  8447.1200  940.391
# 734            1.0                           26.0  8490.1200  616.938
# 735            2.0                           28.0  8490.1200  635.828
# 736            2.0                           27.0  8490.1200  635.828
# 737            1.0                           26.0  8490.1200  616.938
# 738            2.0                           28.0  8490.1200  635.828
# 739            1.0                           29.0  8562.1200  616.938
# 740            2.0                           31.0  8562.1200  635.078
# 741            2.0                           30.0  8562.1200  635.078
# 742            1.0                           29.0  8562.1200  616.938
# 743            2.0                           31.0  8562.1200  635.078
# 745            1.0                           29.0  8562.1200  616.938
# 746            2.0                           31.0  8562.1200  635.078
# 760            1.0                           32.0  8842.1200  918.750
# 761            1.0                           33.0  8874.1200  813.000
# 762            1.0                           34.0  8906.1200  616.938
# 763            2.0                           36.0  8906.1200  643.609
# 764            2.0                           35.0  8906.1200  643.609
# 765            1.0                           34.0  8906.1200  616.938
# 766            2.0                           36.0  8906.1200  643.609
# 778            1.0                           37.0  9005.1200  940.391
#
#         width  height _merge  is_outside
# 6    816.0000   175.0   both           0
# 7    816.0000   175.0   both           0
# 8    816.0000   175.0   both           0
# 9    816.0000   175.0   both           0
# 10   816.0000   175.0   both           0
# 11   816.0000   175.0   both           0
# 12   142.2190    15.0   both           0
# 91    12.5938    15.0   both           0
# 190   16.2969    15.0   both           0
# 201   67.1719    15.0   both           0
# 232   65.4844    15.0   both           0
# 233  142.1720    15.0   both           0
# 234   23.3281    15.0   both           0
# 235  106.6560    15.0   both           0
# 236  106.6560    15.0   both           0
# 237   23.3281    15.0   both           0
# 238  106.6560    15.0   both           0
# 271   15.5469    15.0   both           0
# 338   15.5469    15.0   both           0
# 372   15.5469    15.0   both           0
# 416   15.5469    15.0   both           0
# 473   15.5469    15.0   both           0
# 722   65.4844    15.0   both           0
# 723   84.7969    15.0   both           0
# 724   26.6719    15.0   both           0
# 725   66.1562    15.0   both           0
# 726   66.1562    15.0   both           0
# 727   26.6719    15.0   both           0
# 728   66.1562    15.0   both           0
# 733   22.2188    15.0   both           0
# 734   15.5469    15.0   both           0
# 735  109.2190    15.0   both           0
# 736  109.2190    15.0   both           0
# 737   15.5469    15.0   both           0
# 738  109.2190    15.0   both           0
# 739   14.7969    15.0   both           0
# 740  111.3120    15.0   both           0
# 741  111.3120    15.0   both           0
# 742   14.7969    15.0   both           0
# 743  111.3120    15.0   both           0
# 745   14.7969    15.0   both           0
# 746  111.3120    15.0   both           0
# 760   65.4844    15.0   both           0
# 761  276.9840    15.0   both           0
# 762   23.3281    15.0   both           0
# 763  129.2190    15.0   both           0
# 764  129.2190    15.0   both           0
# 765   23.3281    15.0   both           0
# 766  129.2190    15.0   both           0
# 778   22.2188    15.0   both           0

# %%
def assert_node_ordering_for_merged_table(merged: pd.DataFrame) -> pd.DataFrame:
    '''
    Due to repeat xpaths in both left and right table in merged, need to remove the duplicated rows
    '''
    drop_indices = []
    last_highlight_node_idx = -1
    for i, row in merged[merged['is_outside'] < 1].iterrows():
        if row.exploded_highlight_node_order and row.exploded_highlight_node_order != last_highlight_node_idx + 1:
            drop_indices.append(i)
        else:
            last_highlight_node_idx = row.exploded_highlight_node_order
    merged = merged.drop(drop_indices).reset_index(drop=True)
    
    # Assert both orderings keep their original structure
    assert merged.all_nodes_ordering.is_monotonic_increasing
    assert merged[merged['is_outside'] < 1].exploded_highlight_node_order.is_monotonic_increasing
    
    return merged, drop_indices

# %%
merged, drop_indices = assert_node_ordering_for_merged_table(merged)
merged
# Out:
#                                                  xpaths  \
# 0                              /html/body/document/type
# 1                     /html/body/document/type/sequence
# 2            /html/body/document/type/sequence/filename
# 3     /html/body/document/type/sequence/filename/des...
# 4     /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1775  /html/body/document/type/sequence/filename/des...
# 1776  /html/body/document/type/sequence/filename/des...
# 1777  /html/body/document/type/sequence/filename/des...
# 1778  /html/body/document/type/sequence/filename/des...
# 1779  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 0                                                EX-2.1                   0
# 1                                                     2                   1
# 2                                       d35268dex21.htm                   2
# 3                                                EX-2.1                   3
# 4     EX-2.1 | https://www.sec.gov/Archives/edgar/da...                   4
# ...                                                 ...                 ...
# 1775                         PACIFIC MERCANTILE BANCORP                1776
# 1776                                                By:                1777
# 1777                                /s/ Denis Kalscheur                1778
# 1778                              Name: Denis Kalscheur                1779
# 1779                                    Title: Chairman                1780
#
#      highlighted_xpaths highlighted_segmented_text highlighted_labels  \
# 0                   NaN                        NaN                NaN
# 1                   NaN                        NaN                NaN
# 2                   NaN                        NaN                NaN
# 3                   NaN                        NaN                NaN
# 4                   NaN                        NaN                NaN
# ...                 ...                        ...                ...
# 1775                NaN                        NaN                NaN
# 1776                NaN                        NaN                NaN
# 1777                NaN                        NaN                NaN
# 1778                NaN                        NaN                NaN
# 1779                NaN                        NaN                NaN
#
#       segment_number_from_idx highlighted_coordinates  num_entries_1  \
# 0                         NaN                     NaN            NaN
# 1                         NaN                     NaN            NaN
# 2                         NaN                     NaN            NaN
# 3                         NaN                     NaN            NaN
# 4                         NaN                     NaN            NaN
# ...                       ...                     ...            ...
# 1775                      NaN                     NaN            NaN
# 1776                      NaN                     NaN            NaN
# 1777                      NaN                     NaN            NaN
# 1778                      NaN                     NaN            NaN
# 1779                      NaN                     NaN            NaN
#
#       exploded_highlight_node_order  top  left  width  height     _merge  \
# 0                               NaN  NaN   NaN    NaN     NaN  left_only
# 1                               NaN  NaN   NaN    NaN     NaN  left_only
# 2                               NaN  NaN   NaN    NaN     NaN  left_only
# 3                               NaN  NaN   NaN    NaN     NaN  left_only
# 4                               NaN  NaN   NaN    NaN     NaN  left_only
# ...                             ...  ...   ...    ...     ...        ...
# 1775                            NaN  NaN   NaN    NaN     NaN  left_only
# 1776                            NaN  NaN   NaN    NaN     NaN  left_only
# 1777                            NaN  NaN   NaN    NaN     NaN  left_only
# 1778                            NaN  NaN   NaN    NaN     NaN  left_only
# 1779                            NaN  NaN   NaN    NaN     NaN  left_only
#
#       is_outside
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 1775           1
# 1776           1
# 1777           1
# 1778           1
# 1779           1
#
# [1780 rows x 16 columns]

# %% [markdown]
# Why am I losing rows (1 row now) from the left table?

# %%
df
# Out:
#                                                  xpaths  \
# 0                              /html/body/document/type
# 1                     /html/body/document/type/sequence
# 2            /html/body/document/type/sequence/filename
# 3     /html/body/document/type/sequence/filename/des...
# 4     /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1776  /html/body/document/type/sequence/filename/des...
# 1777  /html/body/document/type/sequence/filename/des...
# 1778  /html/body/document/type/sequence/filename/des...
# 1779  /html/body/document/type/sequence/filename/des...
# 1780  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering
# 0                                                EX-2.1                   0
# 1                                                     2                   1
# 2                                       d35268dex21.htm                   2
# 3                                                EX-2.1                   3
# 4     EX-2.1 | https://www.sec.gov/Archives/edgar/da...                   4
# ...                                                 ...                 ...
# 1776                         PACIFIC MERCANTILE BANCORP                1776
# 1777                                                By:                1777
# 1778                                /s/ Denis Kalscheur                1778
# 1779                              Name: Denis Kalscheur                1779
# 1780                                    Title: Chairman                1780
#
# [1781 rows x 3 columns]

# %%
drop_indices
# Out:
# [235, 237, 725, 727, 735, 737, 740, 742, 745, 746, 763, 765]

# %%
merged[merged['all_nodes_ordering'] == merged.index]
# Out:
#                                                 xpaths  \
# 0                             /html/body/document/type
# 1                    /html/body/document/type/sequence
# 2           /html/body/document/type/sequence/filename
# 3    /html/body/document/type/sequence/filename/des...
# 4    /html/body/document/type/sequence/filename/des...
# ..                                                 ...
# 732  /html/body/document/type/sequence/filename/des...
# 733  /html/body/document/type/sequence/filename/des...
# 734  /html/body/document/type/sequence/filename/des...
# 735  /html/body/document/type/sequence/filename/des...
# 736  /html/body/document/type/sequence/filename/des...
#
#                                                   text  all_nodes_ordering  \
# 0                                               EX-2.1                   0
# 1                                                    2                   1
# 2                                      d35268dex21.htm                   2
# 3                                               EX-2.1                   3
# 4    EX-2.1 | https://www.sec.gov/Archives/edgar/da...                   4
# ..                                                 ...                 ...
# 732  . The Charter and Bylaws of Parent as in effec...                 732
# 733                                                (c)                 733
# 734                               Effect of the Merger                 734
# 735  . At the Effective Time, the effect of the Mer...                 735
# 736                                              3-114                 736
#
#                                     highlighted_xpaths  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 732  /html/body/document/type/sequence/filename/des...
# 733  /html/body/document/type/sequence/filename/des...
# 734  /html/body/document/type/sequence/filename/des...
# 735  /html/body/document/type/sequence/filename/des...
# 736                                                NaN
#
#     highlighted_segmented_text highlighted_labels  segment_number_from_idx  \
# 0                          NaN                NaN                      NaN
# 1                          NaN                NaN                      NaN
# 2                          NaN                NaN                      NaN
# 3                          NaN                NaN                      NaN
# 4                          NaN                NaN                      NaN
# ..                         ...                ...                      ...
# 732                          .               ssst                     21.0
# 733                        (c)               sssn                     20.0
# 734       Effect of the Merger               ssst                     19.0
# 735                          .               ssst                     19.0
# 736                        NaN                NaN                      NaN
#
#                      highlighted_coordinates  num_entries_1  \
# 0                                        NaN            NaN
# 1                                        NaN            NaN
# 2                                        NaN            NaN
# 3                                        NaN            NaN
# 4                                        NaN            NaN
# ..                                       ...            ...
# 732  [8490.12px, 635.828px, 109.219px, 15px]            2.0
# 733  [8562.12px, 616.938px, 14.7969px, 15px]            1.0
# 734  [8562.12px, 635.078px, 111.312px, 15px]            2.0
# 735  [8562.12px, 635.078px, 111.312px, 15px]            2.0
# 736                                      NaN            NaN
#
#      exploded_highlight_node_order      top     left     width  height  \
# 0                              NaN      NaN      NaN       NaN     NaN
# 1                              NaN      NaN      NaN       NaN     NaN
# 2                              NaN      NaN      NaN       NaN     NaN
# 3                              NaN      NaN      NaN       NaN     NaN
# 4                              NaN      NaN      NaN       NaN     NaN
# ..                             ...      ...      ...       ...     ...
# 732                           28.0  8490.12  635.828  109.2190    15.0
# 733                           29.0  8562.12  616.938   14.7969    15.0
# 734                           30.0  8562.12  635.078  111.3120    15.0
# 735                           31.0  8562.12  635.078  111.3120    15.0
# 736                            NaN      NaN      NaN       NaN     NaN
#
#         _merge  is_outside
# 0    left_only           1
# 1    left_only           1
# 2    left_only           1
# 3    left_only           1
# 4    left_only           1
# ..         ...         ...
# 732       both           0
# 733       both           0
# 734       both           0
# 735       both           0
# 736  left_only           1
#
# [737 rows x 16 columns]

# %%
merged[merged['all_nodes_ordering'] > merged.index]
# Out:
#                                                  xpaths  \
# 737   /html/body/document/type/sequence/filename/des...
# 738   /html/body/document/type/sequence/filename/des...
# 739   /html/body/document/type/sequence/filename/des...
# 740   /html/body/document/type/sequence/filename/des...
# 741   /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1775  /html/body/document/type/sequence/filename/des...
# 1776  /html/body/document/type/sequence/filename/des...
# 1777  /html/body/document/type/sequence/filename/des...
# 1778  /html/body/document/type/sequence/filename/des...
# 1779  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 737                                                2.02                 738
# 738                             Closing; Effective Time                 739
# 739                  . The closing of the Merger (the “                 740
# 740                                             Closing                 741
# 741   ”) shall take place\nremotely by mutual exchan...                 742
# ...                                                 ...                 ...
# 1775                         PACIFIC MERCANTILE BANCORP                1776
# 1776                                                By:                1777
# 1777                                /s/ Denis Kalscheur                1778
# 1778                              Name: Denis Kalscheur                1779
# 1779                                    Title: Chairman                1780
#
#      highlighted_xpaths highlighted_segmented_text highlighted_labels  \
# 737                 NaN                        NaN                NaN
# 738                 NaN                        NaN                NaN
# 739                 NaN                        NaN                NaN
# 740                 NaN                        NaN                NaN
# 741                 NaN                        NaN                NaN
# ...                 ...                        ...                ...
# 1775                NaN                        NaN                NaN
# 1776                NaN                        NaN                NaN
# 1777                NaN                        NaN                NaN
# 1778                NaN                        NaN                NaN
# 1779                NaN                        NaN                NaN
#
#       segment_number_from_idx highlighted_coordinates  num_entries_1  \
# 737                       NaN                     NaN            NaN
# 738                       NaN                     NaN            NaN
# 739                       NaN                     NaN            NaN
# 740                       NaN                     NaN            NaN
# 741                       NaN                     NaN            NaN
# ...                       ...                     ...            ...
# 1775                      NaN                     NaN            NaN
# 1776                      NaN                     NaN            NaN
# 1777                      NaN                     NaN            NaN
# 1778                      NaN                     NaN            NaN
# 1779                      NaN                     NaN            NaN
#
#       exploded_highlight_node_order  top  left  width  height     _merge  \
# 737                             NaN  NaN   NaN    NaN     NaN  left_only
# 738                             NaN  NaN   NaN    NaN     NaN  left_only
# 739                             NaN  NaN   NaN    NaN     NaN  left_only
# 740                             NaN  NaN   NaN    NaN     NaN  left_only
# 741                             NaN  NaN   NaN    NaN     NaN  left_only
# ...                             ...  ...   ...    ...     ...        ...
# 1775                            NaN  NaN   NaN    NaN     NaN  left_only
# 1776                            NaN  NaN   NaN    NaN     NaN  left_only
# 1777                            NaN  NaN   NaN    NaN     NaN  left_only
# 1778                            NaN  NaN   NaN    NaN     NaN  left_only
# 1779                            NaN  NaN   NaN    NaN     NaN  left_only
#
#       is_outside
# 737            1
# 738            1
# 739            1
# 740            1
# 741            1
# ...          ...
# 1775           1
# 1776           1
# 1777           1
# 1778           1
# 1779           1
#
# [1043 rows x 16 columns]

# %% [markdown]
# Okay I see what happened. At index 737 for all nodes ordering, somehow the join had a double repeat. All examples of that node in the left dataframe were deleted since 2 highlight nodes before it matched with it. Not sure why tho?

# %% [markdown]
# The (c) node was already matched as well as what followed it but then it and one of the successors was matched again. I think there can be some kind of check to see if highlight node was already matched and if removing current row would destroy the all nodes order, just dont delete the row...
#
# Seems weird but maybe it would work.
#
# Maybe another method could be tracking the start coordinates of the text in each node and then somehow getting a stricter order on that...
#
# Or maybe tracking which char offset from node beginning a highlight belongs to. then if theres overlap in the inveral, we merge, if not we move on. do the same for the all nodes as well

# %% [markdown]
# Let's do the BIES tagging now

# %%
def tag_bies_for_highlights(merged: pd.DataFrame) -> pd.DataFrame:
    
    tags = []
    count = 1
    for i, row in merged.iterrows():
        list_entry_count = row.num_entries_1
        
        # Non highlighted row
        if math.isnan(list_entry_count):
            tags.append('o')
        
        # Single highlighted node
        elif list_entry_count == 1:
            tags.append(f's_{row.highlighted_labels}')
            count = 1
        
        # Last entry in group greater than size 1
        elif count == list_entry_count:
            tags.append(f'e_{row.highlighted_labels}')
            count = 1
        elif (count < list_entry_count) and count == 1:
            tags.append(f'b_{row.highlighted_labels}')
            count += 1
        elif (count < list_entry_count) and count > 1:
            tags.append(f'i_{row.highlighted_labels}')
            count += 1
    merged['tagged_sequence'] = tags
    return merged

# %%
merged = tag_bies_for_highlights(merged)
merged
# Out:
#                                                  xpaths  \
# 0                              /html/body/document/type
# 1                     /html/body/document/type/sequence
# 2            /html/body/document/type/sequence/filename
# 3     /html/body/document/type/sequence/filename/des...
# 4     /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1751  /html/body/document/type/sequence/filename/des...
# 1752  /html/body/document/type/sequence/filename/des...
# 1753  /html/body/document/type/sequence/filename/des...
# 1754  /html/body/document/type/sequence/filename/des...
# 1755  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 0                                                EX-2.1                   0
# 1                                                     2                   1
# 2                                       d35268dex21.htm                   2
# 3                                                EX-2.1                   3
# 4     EX-2.1 | https://www.sec.gov/Archives/edgar/da...                   4
# ...                                                 ...                 ...
# 1751                         PACIFIC MERCANTILE BANCORP                1776
# 1752                                                By:                1777
# 1753                                /s/ Denis Kalscheur                1778
# 1754                              Name: Denis Kalscheur                1779
# 1755                                    Title: Chairman                1780
#
#      highlighted_xpaths highlighted_segmented_text highlighted_labels  \
# 0                   NaN                        NaN                NaN
# 1                   NaN                        NaN                NaN
# 2                   NaN                        NaN                NaN
# 3                   NaN                        NaN                NaN
# 4                   NaN                        NaN                NaN
# ...                 ...                        ...                ...
# 1751                NaN                        NaN                NaN
# 1752                NaN                        NaN                NaN
# 1753                NaN                        NaN                NaN
# 1754                NaN                        NaN                NaN
# 1755                NaN                        NaN                NaN
#
#       segment_number  num_entries_1  exploded_highlight_node_order     _merge  \
# 0                NaN            NaN                            NaN  left_only
# 1                NaN            NaN                            NaN  left_only
# 2                NaN            NaN                            NaN  left_only
# 3                NaN            NaN                            NaN  left_only
# 4                NaN            NaN                            NaN  left_only
# ...              ...            ...                            ...        ...
# 1751             NaN            NaN                            NaN  left_only
# 1752             NaN            NaN                            NaN  left_only
# 1753             NaN            NaN                            NaN  left_only
# 1754             NaN            NaN                            NaN  left_only
# 1755             NaN            NaN                            NaN  left_only
#
#       is_outside tagged_sequence
# 0              1               o
# 1              1               o
# 2              1               o
# 3              1               o
# 4              1               o
# ...          ...             ...
# 1751           1               o
# 1752           1               o
# 1753           1               o
# 1754           1               o
# 1755           1               o
#
# [1756 rows x 12 columns]

# %%
merged[merged['is_outside'] < 1]
# Out:
#                                                  xpaths  \
# 12    /html/body/document/type/sequence/filename/des...
# 13    /html/body/document/type/sequence/filename/des...
# 14    /html/body/document/type/sequence/filename/des...
# 15    /html/body/document/type/sequence/filename/des...
# 16    /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1745  /html/body/document/type/sequence/filename/des...
# 1746  /html/body/document/type/sequence/filename/des...
# 1747  /html/body/document/type/sequence/filename/des...
# 1748  /html/body/document/type/sequence/filename/des...
# 1749  /html/body/document/type/sequence/filename/des...
#
#                                                    text  all_nodes_ordering  \
# 12                                    TABLE OF CONTENTS                  12
# 13                                                 Page                  13
# 14                                             RECITALS                  14
# 15                                            ARTICLE 1                  15
# 16                                  CERTAIN DEFINITIONS                  16
# ...                                                 ...                 ...
# 1745  IN WITNESS WHEREOF, the Parties hereto have ca...                1770
# 1746                           BANC OF CALIFORNIA, INC.                1771
# 1747                                                By:                1772
# 1748                                    /s/ Jared Wolff                1773
# 1749                                  Name: Jared Wolff                1774
#
#                                      highlighted_xpaths  \
# 12    /html/body/document/type/sequence/filename/des...
# 13    /html/body/document/type/sequence/filename/des...
# 14    /html/body/document/type/sequence/filename/des...
# 15    /html/body/document/type/sequence/filename/des...
# 16    /html/body/document/type/sequence/filename/des...
# ...                                                 ...
# 1745  /html/body/document/type/sequence/filename/des...
# 1746  /html/body/document/type/sequence/filename/des...
# 1747  /html/body/document/type/sequence/filename/des...
# 1748  /html/body/document/type/sequence/filename/des...
# 1749  /html/body/document/type/sequence/filename/des...
#
#                              highlighted_segmented_text highlighted_labels  \
# 12                                    TABLE OF CONTENTS                 st
# 13                                                 Page                 st
# 14                                             RECITALS                 st
# 15                                            ARTICLE 1                 st
# 16                                  CERTAIN DEFINITIONS                 st
# ...                                                 ...                ...
# 1745  IN WITNESS WHEREOF, the Parties hereto have ca...                  n
# 1746                           BANC OF CALIFORNIA, INC.                  n
# 1747                                                By:                  n
# 1748                                    /s/ Jared Wolff                  n
# 1749                                      Name: Jared W                  n
#
#       segment_number  num_entries_1  exploded_highlight_node_order _merge  \
# 12               0.0           15.0                            0.0   both
# 13               0.0           15.0                            1.0   both
# 14               0.0           15.0                            2.0   both
# 15               0.0           15.0                            3.0   both
# 16               0.0           15.0                            4.0   both
# ...              ...            ...                            ...    ...
# 1745            28.0            5.0                          285.0   both
# 1746            28.0            5.0                          286.0   both
# 1747            28.0            5.0                          287.0   both
# 1748            28.0            5.0                          288.0   both
# 1749            28.0            5.0                          289.0   both
#
#       is_outside tagged_sequence
# 12             0            b_st
# 13             0            i_st
# 14             0            i_st
# 15             0            i_st
# 16             0            i_st
# ...          ...             ...
# 1745           0             b_n
# 1746           0             i_n
# 1747           0             i_n
# 1748           0             i_n
# 1749           0             e_n
#
# [290 rows x 12 columns]

# %%
merged.to_csv('overlabeled_labeled.csv')

# %% [markdown]
# I think I need to modify this algorithm. The overlabeled file that I just tried somehow labeled index 245 as b_n but i think its a single highlight node? It looks like the master nodes might be traversing in a different order tbh not sure, I did label pretty wildly... but still not sure how that happens?

# %%
highlighted_df.iloc[2]
# Out:
# highlighted_xpaths            [/html/body/document/type/sequence/filename/de...
# highlighted_segmented_text    [” has the meaning set forth in Section 6.03(d...
# highlighted_labels                                                            n
# segment_number                                                                2
# num_entries_1                                                                22
# num_entries_2                                                                22
# Name: 2, dtype: object

# %%
highlighted_df.iloc[2]['highlighted_xpaths']
# Out:
# ['/html/body/document/type/sequence/filename/description/text/center[5]/div/p[7]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[8]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[8]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[8]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[9]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[9]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[9]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[10]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[10]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[10]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[11]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[11]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[11]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[12]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[12]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[12]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[13]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[13]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[13]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[14]',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[14]/i',
#  '/html/body/document/type/sequence/filename/description/text/center[5]/div/p[14]']
